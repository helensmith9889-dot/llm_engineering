# %% [markdown]
# # 收集必要的诊断信息
#
# ## 请运行下一个单元格以收集一些重要数据
#
# 请运行下一个单元格；大约需要一分钟左右（主要是网络测试）。
# 然后把最后一个单元格的输出发邮件给我：ed@edwarddonner.com。
# 或者：这会创建一个名为 report.txt 的文件——直接把该文件作为附件发邮件即可。

# %%
# 运行我的诊断报告，收集用于调试的关键信息
# 请把结果发邮件给我。可以复制粘贴输出，或附上 report.txt 文件

# !pip install -q requests speedtest-cli psutil setuptools
from diagnostics import Diagnostics
Diagnostics().run()
