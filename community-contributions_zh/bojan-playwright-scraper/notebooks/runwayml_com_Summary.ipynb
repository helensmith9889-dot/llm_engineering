# %% [markdown]
# # 网站摘要：runwayml.com
#
# 由 **Playwright AI 爬虫**自动生成的结构化摘要 notebook（本仓库 `bojan-playwright-scraper` 流水线产出）。
#
# ## 这是什么
#
# 爬虫先用 Playwright 打开目标站、抓取可见正文，再把正文交给 LLM，按固定栏目（摘要 / 实体 / 更新 / 主题 / 功能）写成下面这一格 Markdown。
#
# ## 和本课的关系
#
# | 本课概念 | 这里对应什么 |
# |----------|----------------|
# | 网页抓取 | Playwright 处理 JS 渲染页（比裸 HTTP 更能拿到动态内容） |
# | 网站摘要 | 把抓到的正文压成可读结构化分析 |
# | Chat Completions | 摘要文案由模型生成（本 notebook 只保存结果，不再次调 API） |
#
# ## 怎么读
#
# 1. 先看 **URL**，确认摘要对应的站点
# 2. 再按「摘要 → 实体 → 更新 → 主题 → 功能」扫一遍
# 3. 若某栏写「信息不足」或缺少近期动态，多半是抓取片段有限——应回源站或加强爬虫选择器，而不是迷信摘要

# %% [markdown]
# # 摘要目标站：https://runwayml.com
#
# 本 notebook 保存的是对该网站内容的 **AI 生成结构化摘要**（教学注释：下列分析由流水线产出，已译为中文便于阅读；事实以源站为准）。
#
# **URL**：`https://runwayml.com`
#
# ---
#
# **分析（Analysis）**：
#
# ### 摘要（Summary）
#
# 站点在宣传一系列用 **Gen-4** 制作的短片。Gen-4 被描述为面向媒体生成、并强调「世界一致性（world consistency）」的下一代 AI 模型系列。页面重点多半是展示这些模型在电影创作中的能力。
#
# ### 实体（Entities）
#
# - **Gen-4**：用于制作短片的 AI 模型系列。
# - 除这项 AI 技术外，抓取内容未点名更多具体个人或组织。
#
# ### 更新（Updates）
#
# - 当前片段里没有给出具体的近期公告或新闻更新。
#
# ### 主题（Topics）
#
# - **AI 电影制作（AI in Filmmaking）**：用先进 AI 模型参与影片创作。
# - **短片（Short Films）**：出现如 *The Lonely Little Flame*、*NYC is a Zoo*、*The Herd* 等片名，说明偏叙事短片方向。
# - **媒体生产中的技术**：强调 Gen-4 在媒体制作中的角色。
#
# ### 功能 / 项目（Features）
#
# - **Gen-4 AI 模型**：被突出为媒体生成方面的重要创新。
# - **短片作品**：上述片名是用 Gen-4 技术完成的项目示例。
# - **互动入口**：如 “Try Runway Now”“Learn More About Gen-4” 等，引导访客试用或深入了解技术。
#
# 若要做更全面的分析，还需要 Gen-4 的具体能力说明、组织背景，或各短片的更详细描述。
