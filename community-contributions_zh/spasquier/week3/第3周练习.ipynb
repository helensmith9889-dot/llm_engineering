# %% [markdown]
# # 具有模型选择和 Gradio UI 的综合数据生成器（第 3 周练习）
#
# ## 练习目标（理念）
#
# 为**库存管理聊天机器人**准备示例/种子数据：用户可通过对话更新库存；本练习侧重点是「综合数据生成 + 可选模型 + Gradio UI」。
#
# ## 和本课 Week 3 的关系
#
# | 本课概念 | 本练习预期你会练到 |
# |----------|-------------------|
# | 合成 / 种子数据 | 为下游库存机器人准备可对话更新的样例 |
# | 模型选择 | UI 或代码里切换不同 LLM |
# | Gradio | 用网页交互触发生成与预览 |
#
# ## 怎么跑
#
# 作者把完整实现放在 Google Colab；请打开下方链接按笔记本单元格顺序运行（需自备对应 API / 运行时）。
#
# [https://colab.research.google.com/drive/1Tt8fOXVq1yIih1quZIH-MHcjSfN6_01w](https://colab.research.google.com/drive/1Tt8fOXVq1yIih1quZIH-MHcjSfN6_01w)
