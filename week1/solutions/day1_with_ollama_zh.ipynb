# %% [markdown]
# # 使用 OLLAMA 的 Day 1 替代方案
#
# ### 请阅读本节。即便篇幅较长，这些内容也很重要，能帮你做好准备。
#
# ## 你的第一个前沿 LLM 项目
#
# 让我们在几分钟内构建一个有用的 LLM 方案。
#
# 到本课程结束时，你将构建一个由 7 个智能体协作解决业务问题的自主 Agentic AI 方案。别急，我们会循序渐进！先从更小的事情开始……
#
# 我们的目标是编写一种新型网页浏览器：给定一个 URL，它会返回摘要——互联网版的《读者文摘》！！
#
# 开始之前，你应该已完成 [PC](../SETUP-PC.md) 或 [Mac](../SETUP-mac.md) 的配置，并且最好是在项目根目录下、环境已激活的情况下启动了这个 jupyter lab。
#
# ## 如果你刚接触 Jupyter Lab
#
# 欢迎来到数据科学实验的奇妙世界！一旦用过 Jupyter Lab，你会怀疑以前没有它是怎么活下来的。只需点击下方这类包含代码的「单元格」，然后按 Shift+Return 执行。你也可以用工具栏的 + 按钮添加单元格，打印变量值，或尝试变体。
#
# 我写了一个名为 [Guide to Jupyter](Guide%20to%20Jupyter.ipynb) 的 notebook，帮助你更熟悉 Jupyter Labs，包括添加 Markdown 注释、用 `!` 运行 shell 命令，以及用 `tqdm` 显示进度。
#
# ## 如果你刚接触命令行
#
# 请查看这些优秀指南：[PC 上的命令行](https://chatgpt.com/share/67b0acea-ba38-8012-9c34-7a2541052665) 和 [Mac 上的命令行](https://chatgpt.com/canvas/shared/67b0b10c93a081918210723867525d2b)。
#
# ## 如果你更喜欢在 IDE 中工作
#
# 如果你更习惯 VSCode 或 Pycharm 这类 IDE，它们也能很好地配合这些实验 notebook。
# 如果想用 VSCode，[这里](https://chatgpt.com/share/676f2e19-c228-8012-9911-6ca42f8ed766) 有一位 AI 朋友提供的课程配置说明。
#
# ## 如果你想复习 Python
#
# 我添加了一个名为 [Intermediate Python](Intermediate%20Python.ipynb) 的 notebook 帮你跟上进度。但如果你已经清楚这段代码在做什么，可以跳过：
# `yield from {book.get("author") for book in books if book.get("author")}`
#
# ## 我随时可以帮忙
#
# 如果遇到任何问题，请随时联系我。
# 你可以通过课程平台联系我，也可以发邮件到 ed@edwarddonner.com，或访问 https://www.linkedin.com/in/eddonner/ 与我连接（我很喜欢和大家交流！）
# 这对我来说还挺新鲜的——我也在 X/Twitter 上尝试 [@edwarddonner](https://x.com/edwarddonner)；如果你也在用 X，请教教我怎么玩 😂
#
# ## 更多故障排查
#
# 请查看本文件夹中的 [troubleshooting](troubleshooting.ipynb) notebook，用于诊断和修复常见问题。文件末尾有一个诊断脚本，可提供有用的调试信息。
#
# ## 如果这些对你来说已经很熟悉！
#
# 如果你已经熟悉今天的内容，请耐心一点；前几个实验你可以快速过一遍——随着课程推进我们会越来越深入。
#
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../../important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">请阅读——重要说明</h2>
#             <span style="color:#900;">我与你协作的方式可能和其他课程不同。我不喜欢在你看着的时候现场敲代码。相反，我会像这样执行 Jupyter Labs，并帮你建立对正在发生之事的直觉。我的建议是：在观看讲座<strong>之后</strong>，仔细地自己执行一遍。添加 print 语句来理解发生了什么，然后想出你自己的变体。如果你有 Github 账号，用它来展示你的变体。这不仅是必要的练习，也能向他人（包括未来的客户或雇主）展示你的技能……</span>
#         </td>
#     </tr>
# </table>
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../../resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">把这些实验当作资源</h2>
#             <span style="color:#f71;">我会定期推送代码更新。当有人提问或遇到问题时，我会把它纳入代码，添加更多示例或改进说明。因此你会发现下面的代码与视频并不完全相同。视频中的内容都在这里；此外，我还添加了更多步骤和更好的解释，偶尔也会加入像 DeepSeek 这样的新模型。请把这当作一本配合讲座的交互式书。
#             </span>
#         </td>
#     </tr>
# </table>
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../../business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">这些练习的商业价值</h2>
#             <span style="color:#181;">最后一点想法。虽然我把这些 notebook 设计成教学用途，但也尽量让它们有趣。我们会做一些有意思的事，比如让 LLM 讲笑话、互相辩论。但从根本上说，我的目标是传授你可以在商业中应用的技能。我会在过程中解释商业含义，值得牢记的是：随着你积累模型与技术经验，想想今天就能在工作中落地的方式。如果你想进一步讨论，或有想法想和我碰撞，请务必联系我。</span>
#         </td>
#     </tr>
# </table>

# %%
# 导入

# 导入标准库 os（操作系统相关，用来读环境变量 Environment Variables）
import os
# 导入 requests：用 HTTP 发网络请求（比手写 urllib 更简单）
import requests
# 从 dotenv 导入 load_dotenv：把 .env 文件里的密钥读进环境变量，避免把密钥写进代码
from dotenv import load_dotenv
# 从 bs4 导入 BeautifulSoup：解析 HTML 网页，方便提取标题和正文
from bs4 import BeautifulSoup
# 从 IPython.display 导入展示工具：在 Jupyter 笔记本里漂亮地显示 Markdown/图片等
from IPython.display import Markdown, display
# 从 openai 导入 OpenAI 客户端类：用它调用 Chat Completions 等 API（Application Programming Interface）
from openai import OpenAI

# 如果运行此单元格出错，请前往 troubleshooting notebook！

# %% [markdown]
# # 连接到 OpenAI
#
# 下一个单元格会加载你 `.env` 文件中的环境变量并连接到 OpenAI。
#
# ## 遇到问题时的排查：
#
# 请前往本文件夹中的 [troubleshooting](troubleshooting.ipynb) notebook，按步骤识别根本原因并修复！
#
# 如果你做了更改，请尝试通过 Kernel 菜单 >> Restart Kernel and Clear Outputs of All Cells 重启「Kernel」（支撑本 notebook 的 Python 进程）。然后从顶部重新开始运行本 notebook。
#
# 或者联系我！私信我或发邮件到 ed@edwarddonner.com，我们一起把它搞定。
#
# 担心 API 费用？请看 README 中的说明——费用应该很低，而且你可以随时控制。你也可以使用 Ollama 作为免费替代，我们会在 Day 2 讨论。

# %% [markdown]
# # 现在是针对 Ollama 的改动
#
# 1. 不需要环境变量（不需要密钥），所以这部分已被移除
#
# 2. OpenAI 客户端库被初始化为指向你本地电脑上的 Ollama
#
# 3. 你需要已在电脑上安装 Ollama，如果还没有，请在 Powershell 或 Terminal 中运行 `ollama run llama3.2`
#
# 4. 本实验中凡是原来使用 **gpt-4o-mini** 的地方，现在都改成了 **llama3.2**

# %%
# 就是这里——看 base_url

openai = OpenAI(base_url='http://localhost:11434/v1', api_key='ollama')

# %% [markdown]
# # 让我们先快速调用一次前沿模型，作为预览！

# %%
# 给你一个预览——用这些消息调用 OpenAI 就是这么简单。有问题请前往 Troubleshooting notebook。

message = "Hello, Llama! This is my first ever message to you! Hi!"
# 调用 chat.completions.create：向大模型发一次对话请求并拿回复（同步、等全部生成完）
response = openai.chat.completions.create(model="llama3.2", messages=[{"role":"user", "content":message}])
print(response.choices[0].message.content)

# %% [markdown]
# ## 好，继续我们的第一个项目

# %%
# 表示网页的类
# 如果你不熟悉类，请查看 "Intermediate Python" notebook

# 有些网站在抓取时需要你使用正确的请求头：
headers = {
 "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/117.0.0.0 Safari/537.36"
}

# Website 类：封装「下载网页 + 解析标题/正文」；不懂类可先把它当成自定义数据类型
class Website:

    # 定义函数：把一组步骤打包，方便重复调用
    def __init__(self, url):
        """
        Create this Website object from the given url using the BeautifulSoup library
        """
        self.url = url
        response = requests.get(url, headers=headers)
        soup = BeautifulSoup(response.content, 'html.parser')
        self.title = soup.title.string if soup.title else "No title found"
        for irrelevant in soup.body(["script", "style", "img", "input"]):
            irrelevant.decompose()
        self.text = soup.body.get_text(separator="\n", strip=True)

# %%
# 让我们试一个。更改网站并添加 print 语句以跟上进度。

ed = Website("https://edwarddonner.com")
print(ed.title)
print(ed.text)

# %% [markdown]
# ## 提示词的类型
#
# 你可能已经知道了——如果还不知道，很快就会非常熟悉！
#
# 像 GPT4o 这样的模型被训练成以特定方式接收指令。
#
# 它们期望收到：
#
# **系统提示词（system prompt）**，告诉它们正在执行什么任务、应使用什么语气
#
# **用户提示词（user prompt）**——它们应回复的对话开场白

# %%
# 定义我们的系统提示词——你可以稍后实验，把最后一句改成 'Respond in markdown in Spanish."

system_prompt = "You are an assistant that analyzes the contents of a website \
and provides a short summary, ignoring text that might be navigation related. \
Respond in markdown."

# %%
# 编写用户提示词、请求网站摘要的函数：

def user_prompt_for(website):
    # 用户提示词（user prompt）：本次要模型完成的具体任务与输入内容
    user_prompt = f"You are looking at a website titled {website.title}"
    user_prompt += "\nThe contents of this website is as follows; \
please provide a short summary of this website in markdown. \
If it includes news or announcements, then summarize these too.\n\n"
    user_prompt += website.text
    return user_prompt

# %%
print(user_prompt_for(ed))

# %% [markdown]
# ## 消息（Messages）
#
# OpenAI 的 API 期望以特定结构接收消息。
# 许多其他 API 也使用这种结构：
#
# ```
# [
#     {"role": "system", "content": "system message goes here"},
#     {"role": "user", "content": "user message goes here"}
# ]
#
# 先给你一个预览：接下来两个单元格会做一个相当简单的调用——我们还不会（暂时！）为难强大的 GPT

# %%
# 组装 messages 列表：Chat Completions API 要求的对话格式（system / user / assistant）
messages = [
    {"role": "system", "content": "You are a snarky assistant"},
    {"role": "user", "content": "What is 2 + 2?"}
]

# %%
# 给你一个预览——用系统消息和用户消息调用 OpenAI：

response = openai.chat.completions.create(model="llama3.2", messages=messages)
print(response.choices[0].message.content)

# %% [markdown]
# ## 现在让我们用函数为 GPT-4o-mini 构建有用的消息

# %%
# 看看这个函数如何精确创建上面的格式

def messages_for(website):
    return [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt_for(website)}
    ]

# %%
# 试试看，然后再试几个网站

messages_for(ed)

# %% [markdown]
# ## 是时候把它们整合起来了——OpenAI 的 API 非常简单！

# %%
# 现在：调用 OpenAI API。你会对此非常熟悉！

def summarize(url):
    # 抓取/构造网站内容，作为后续提示词的输入
    website = Website(url)
    # 调用 chat.completions.create：向大模型发一次对话请求并拿回复（同步、等全部生成完）
    response = openai.chat.completions.create(
        model = "llama3.2",
        # 组装 messages 列表：Chat Completions API 要求的对话格式（system / user / assistant）
        messages = messages_for(website)
    )
    return response.choices[0].message.content

# %%
summarize("https://edwarddonner.com")

# %%
# 用 markdown 在 Jupyter 输出中美观地显示结果的函数

def display_summary(url):
    # 拿到模型生成的摘要文本
    summary = summarize(url)
    # 用 Markdown 在笔记本中渲染格式化文本（display_id 方便后续原地刷新）
    display(Markdown(summary))

# %%
display_summary("https://edwarddonner.com")

# %% [markdown]
# # 让我们试试更多网站
#
# 注意：这只适用于可以用这种简单方式抓取的网站。
#
# 用 Javascript 渲染的网站（如 React 应用）不会显示内容。请查看 community-contributions 文件夹中的 Selenium 实现来绕过此限制。你需要了解如何安装 Selenium（可以问 ChatGPT！）
#
# 另外，受 CloudFront（及类似服务）保护的网站可能会返回 403 错误——非常感谢 Andy J 指出这一点。
#
# 但许多网站都能正常工作！

# %%
display_summary("https://cnn.com")

# %%
display_summary("https://anthropic.com")

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../../business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">商业应用</h2>
#             <span style="color:#181;">在本练习中，你第一次体验了调用前沿模型（处于 AI 前沿的领先模型）的云端 API。在本课程的许多阶段我们都会使用像 OpenAI 这样的 API，此外还会构建我们自己的 LLM。
#
# 更具体地说，我们把它用在了摘要（Summarization）上——这是生成摘要的经典 Gen AI 用例。它可以应用于任何业务领域——总结新闻、总结财务表现、把简历总结进求职信——应用场景无穷无尽。想想你如何在业务中应用摘要，并尝试制作一个原型。</span>
#         </td>
#     </tr>
# </table>
#
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../../important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">继续之前——现在自己试试</h2>
#             <span style="color:#900;">使用下方单元格制作你自己的简单商业示例。目前先继续使用摘要用例。这里有一个想法：写一个程序，接收邮件内容，并建议一个合适的简短主题行。这正是可能被集成到商业邮件工具中的功能类型。</span>
#         </td>
#     </tr>
# </table>

# %%
# 步骤 1：创建你的提示词

system_prompt = "something here"
# 用户提示词（user prompt）：本次要模型完成的具体任务与输入内容
user_prompt = """
    Lots of text
    Can be pasted here
"""

# 步骤 2：构建 messages 列表

messages = [] # fill this in

# 步骤 3：调用 OpenAI

response =

# 步骤 4：打印结果

print(

# %% [markdown]
# ## 给喜欢网页抓取的人的额外练习
#
# 你可能注意到，如果尝试 `display_summary("https://openai.com")`——它没法用！因为 OpenAI 有一个使用 Javascript 的精美网站。有许多绕过方法，你们中一些人可能已经熟悉。例如，Selenium 是一个非常流行的框架，它在后台运行浏览器、渲染页面，并允许你查询它。如果你有 Selenium、Playwright 或类似工具的经验，可以随意改进 Website 类来使用它们。在 community-contributions 文件夹中，你会找到一位学员贡献的 Selenium 示例（谢谢！）

# %% [markdown]
# # 分享你的代码
#
# 我很希望你之后分享代码，这样我就能分享给其他人！你会注意到一些学员已经做了改动（包括 Selenium 实现），可以在 community-contributions 文件夹中找到。如果想把你的改动加入该文件夹，请提交包含新版本的 Pull Request，我会合并你的更改。
#
# 如果你不是 git 专家（我也不是！），GPT 给出了一些不错的关于如何提交 Pull Request 的说明。过程有点繁琐，但做过一次就很清楚了。小贴士：最好清空 Jupyter notebook 的输出（Edit >> Clean outputs of all cells，然后 Save），以保持 notebook 干净。
#
# 以下是一位 AI 朋友提供的不错说明：
# https://chatgpt.com/share/677a9cb5-c64c-8012-99e0-e06e88afd293
