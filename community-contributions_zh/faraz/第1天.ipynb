# %% [markdown]
# # 你的第一个实验室
# ### 请阅读本节。这对于让你做好准备很有价值，即使它是一篇很长的文章——它很重要。
#
# ### 另外，请务必阅读[README.md](../README.md)！有关自述文件中更新视频的更多信息和[紫色课程资源顶部](https://edwarddonner.com/2024/11/13/llm-engineering-resources/)
#
# ## 您的第一个前沿法学硕士项目
#
# 在本课程结束时，您将构建一个由 7 个代理协作解决业务问题的自主代理 AI 解决方案。一切都恰逢其时！我们将从更小的事情开始......
#
# 我们的目标是编写一种新型的 Web 浏览器。给它一个 URL，它会返回一个摘要。互联网读者文摘！！
#
# 在开始之前，您应该已经完成​​自述文件中链接的设置。
#
# ### 如果您刚开始使用“笔记本”（也称为实验室或 Jupyter 实验室）
#
# 欢迎来到数据科学实验的奇妙世界！只需单击其中包含代码的每个“单元格”（例如紧邻此文本下方的单元格），然后按 Shift+Return 即可执行该单元格。确保从顶部开始按顺序运行每个单元格。
#
# 请在 [Guides 文件夹](../guides/01_intro.ipynb) 中查找所有指南。
#
# ## 我是来帮忙的
#
# 如果您有任何问题，请联系我们。
# 如果您想联系，可以通过该平台或 ed@edwarddonner.com 或 https://www.linkedin.com/in/eddonner/ 与我联系（我喜欢联系！）
# 我还有一个[包含额外内容的 YouTube 频道](https://youtube.com/@edward.donner)。
# 这对我来说是新的，但我也在 [@edwarddonner](https://x.com/edwarddonner) 尝试 X - 如果你在 X，请告诉我它是如何完成的 😂
#
# ## 更多疑难解答
#
# 请参阅安装文件夹中的[故障排除](../setup/troubleshooting.ipynb) 笔记本来诊断和修复常见问题。最后是一个诊断脚本，其中包含一些有用的调试信息。
#
# ## 如果这是旧帽子！
#
# 如果您已经熟悉今天的内容，请坚持下去；您可以快速完成前几个实验 - 随着几周的进展，我们将获得更深入的了解。最终我们会微调我们自己的LLM来与OpenAI竞争！
#
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="宽度：150px；高度：150px；垂直对齐：中间；">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">请阅读 - 重要说明</h2>
#             <span style="color:#900;">我与您合作的方式可能与您参加的其他课程不同。我不喜欢在你观看时输入代码。相反，我会像这样执行 Jupyter Labs，并让您对正在发生的事情有一个直观的了解。我的建议是，<b>观看讲座之后</b>，您自己仔细执行此操作。添加打印语句以了解发生了什么，然后提出您自己的变体。如果您有 Github 帐户，请使用它来展示您的变体。这不仅是必要的实践，而且还可以向其他人（包括未来的客户或雇主）展示您的技能......</span>
#         </td>
#     </tr>
# </表>
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="宽度：150px；高度：150px；垂直对齐：中间；">
#             <img src="../assets/resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">此代码是实时资源 - 请留意我的电子邮件</h2>
#             <span style="color:#f71;">我定期推送代码更新。当人们提出问题时，我会添加更多示例或改进评论。因此，您会注意到下面的代码与视频不同。视频中的所有内容都在这里；但我还添加了更好的解释和新模型，例如 DeepSeek。将其视为一本互动书。<br/><br/>
#                 我尝试定期发送电子邮件，其中包含与课程相关的重要更新。您可以在 Udemy 左侧边栏的“公告”部分找到此内容。您还可以选择通过 Udemy 中的通知设置接收我的电子邮件。我尊重您的收件箱，并始终尝试通过我的电子邮件增加价值！
#             </span>
#         </td>
#     </tr>
# </表>
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="宽度：150px；高度：150px；垂直对齐：中间；"><img src="../assets/business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">这些练习的商业价值</h2>
#             <span style="color:#181;">最后一个想法。虽然我设计这些笔记本是为了具有教育意义，但我也努力让它们变得有趣。我们会做一些有趣的事情，比如让法学硕士讲笑话和互相争论。但从根本上来说，我的目标是教授可应用于商业的技能。我将在讨论过程中解释业务影响，值得记住这一点：当您积累模型和技术经验时，请考虑如何将其付诸实践。如果您想讨论更多内容或者有想法可以向我反馈，请与我联系。</span>
#         </td>
#     </tr>
# </表>

# %% [markdown]
# ### 如果需要，安装游标扩展
#
# 1. 从“查看”菜单中，选择“扩展”
# 2. 搜索Python
# 3. 单击“ms-python”制作的“Python”，如果尚未安装，则选择“安装”
# 4.搜索Jupyter
# 5. 单击“ms-toolsai”制作的“Jupyter”，如果尚未安装，则选择“安装”
#
#
# ### 接下来选择内核
#
# 点击右上角的“选择内核”
#
# 选择“Python 环境...”
#
# 然后选择看起来像“.venv (Python 3.12.x) .venv/bin/python”的那个 - 它应该被标记为“推荐”，并且旁边有一个大星。
#
# 这有什么问题吗？前往故障排除。
#
# ### 注意：您需要为每个笔记本设置内核..

# %%
# 进口

import os
from dotenv import load_dotenv
from scraper import fetch_website_contents
from IPython.display import Markdown, display
from openai import OpenAI

# 如果运行此单元时出现错误，请转到故障排除笔记本！

# %% [markdown]
# # 连接到 OpenAI（或 Ollama）
#
# 下一个单元格是我们加载“.env”文件中的环境变量并连接到 OpenAI 的位置。
#
# 如果您想使用免费的 Ollama，请参阅自述文件部分“付费 API 的免费替代方案”，如果您不确定如何执行此操作，解决方案文件夹 (day1_with_ollama.ipynb) 中有完整的解决方案。
#
# ## 如果遇到问题，请进行故障排除：
#
# 如果您收到“名称错误” - 您是否从上到下运行所有单元格？请参阅 Python 基础指南，了解查找和修复所有名称错误的万无一失的方法。
#
# 如果这不能解决问题，请转到[故障排除](../setup/troubleshooting.ipynb) 笔记本，获取分步代码来识别根本原因并修复它！
#
# 或者，联系我！请给我留言或发送电子邮件至 ed@edwarddonner.com，我们将让其发挥作用。
#
# 对 API 成本有任何担忧吗？请参阅我在自述文件中的注释 - 成本应该是最低的，并且您可以在每个点上控制它。您还可以使用 Ollama 作为免费替代方案，我们将在第 2 天讨论这一点。

# %%
# 在名为 .env 的文件中加载环境变量

load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

# 检查钥匙

if not api_key:
    print("No API key was found - please head over to the troubleshooting notebook in this folder to identify & fix!")
elif not api_key.startswith("sk-proj-"):
    print("An API key was found, but it doesn't start sk-proj-; please check you're using the right key - see troubleshooting notebook")
elif api_key.strip() != api_key:
    print("An API key was found, but it looks like it might have space or tab characters at the start or end - please remove them - see troubleshooting notebook")
else:
    print("API key found and looks good so far!")
# Out:
# API key found and looks good so far!

# %% [markdown]
# # 让我们快速调用 Frontier 模型来开始，作为预览！

# %%
# 让您预览一下——使用这些消息调用 OpenAI 就是这么简单。如有任何问题，请参阅故障排除笔记本。

message = "Hello, GPT! This is my first ever message to you! Hi!"

messages = [{"role": "user", "content": message}]

messages
# Out:
# [{'role': 'user',
#   'content': 'Hello, GPT! This is my first ever message to you! Hi!'}]

# %%
openai = OpenAI()

response = openai.chat.completions.create(model="gpt-5-nano", messages=messages)
response.choices[0].message.content
# Out:
# 'Hi there! Nice to meet you. Welcome to our chat.\n\nWhat would you like to do today? I can help with:\n- Answering questions or explaining topics\n- Writing, editing, or brainstorming (essays, emails, stories)\n- Coding, math, science help\n- Summaries, study guides, or flashcards\n- Planning, ideas, or casual chat\n\nTell me a topic or task, and we’ll get started. What would you like to try first?'

# %% [markdown]
# ## 开始我们的第一个项目

# %%
# 让我们尝试一下这个实用程序

ed = fetch_website_contents("https://edwarddonner.com")
print(ed)
# Out:
# Home - Edward Donner
#
# Skip to content
# Avatar
# Curriculum
# Proficiency
# C4
# Outsmart
# An arena that pits LLMs against each other in a battle of diplomacy and deviousness
# About
# Posts
# Well, hi there.
# I’m Ed. I like writing code and experimenting with LLMs, and hopefully you’re here because you do too. I also enjoy amateur electronic music production (
# very
# amateur) and losing myself in
# Hacker News
# , nodding my head sagely to things I only half understand.
# I’m the co-founder and CTO of AI startup
# Nebula.io
# . I was previously founder and CEO of AI startup untapt,
# acquired in 2021
# , and a Managing Director at JPMorgan.
# I will happily drone on for hours about LLMs to anyone in my vicinity. My friends got fed up with my impromptu lectures, and convinced me to make some Udemy courses. To my total joy (and shock) they’ve become best-selling, top-rated courses, with 600,000 enrolled across 194 countries. The
# full curriculum is here
# ...

# %% [markdown]
# ## 提示类型
#
# 您可能已经知道这一点 - 但如果不知道，您将会非常熟悉它！
#
# 像 GPT 这样的模型已经过训练，可以以特定方式接收指令。
#
# 他们期望收到：
#
# **系统提示**告诉他们正在执行什么任务以及应该使用什么语气
#
# **用户提示**——他们应该回复的对话开始者

# %%
# 定义我们的系统提示符 - 您可以稍后进行实验，将最后一句更改为“用西班牙语以 markdown 方式回复”。

system_prompt = """
You are a snarky assistant that analyzes the contents of a website,
and provides a short, snarky, humorous summary, ignoring text that might be navigation related.
Respond in markdown. Do not wrap the markdown in a code block - respond just with the markdown.
"""

# %%
# 定义我们的用户提示

user_prompt_prefix = """
Here are the contents of a website.
Provide a short summary of this website.
If it includes news or announcements, then summarize these too.

"""

# %% [markdown]
# ## 消息
#
# OpenAI 的 API 期望接收特定结构的消息。
# 许多其他 API 共享此结构：```python
# [
#     {"role": "system", "content": "system message goes here"},
#     {"role": "user", "content": "user message goes here"}
# ]
# ```为了给您一个预览，接下来的 2 个单元格进行了一个相当简单的调用 - 我们不会扩展强大的 GPT（还！）

# %%
messages = [
    {"role": "system", "content": "You are a helpful assistant"},
    {"role": "user", "content": "What is 2 + 2?"}
]

response = openai.chat.completions.create(model="gpt-4.1-nano", messages=messages)
response.choices[0].message.content
# Out:
# '2 + 2 equals 4.'

# %% [markdown]
# ## 现在让我们使用函数为 GPT-4.1-mini 构建有用的消息

# %%
# 看看这个函数如何创建与上面完全相同的格式

def messages_for(website):
    return [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt_prefix + website}
    ]

# %%
# 尝试一下，然后再尝试几个网站

messages_for(ed)
# Out:
# [{'role': 'system',
#   'content': '\nYou are a snarky assistant that analyzes the contents of a website,\nand provides a short, snarky, humorous summary, ignoring text that might be navigation related.\nRespond in markdown. Do not wrap the markdown in a code block - respond just with the markdown.\n'},
#  {'role': 'user',
# ...

# %% [markdown]
# ## 是时候将它们整合在一起了 - OpenAI 的 API 非常简单！

# %%
# 现在：调用 OpenAI API。你将会对此非常熟悉！

def summarize(url):
    website = fetch_website_contents(url)
    response = openai.chat.completions.create(
        model = "gpt-4.1-mini",
        messages = messages_for(website)
    )
    return response.choices[0].message.content

# %%
summarize("https://edwarddonner.com")
# Out:
# '# Edward Donner’s Website: The LLM Whisperer’s Lair\n\nWelcome to Ed’s personal playground where coding meets AI obsession and amateur electronic music (yes, really). Ed’s the AI startup maestro behind Nebula.io, ex-founder of an AI company that got snapped up in 2021, and a former JPMorgan bigwig. When he’s not drowning in code, he’s inundating friends with LLM lectures—so he made some Udemy courses to channel that energy, which apparently became wildly popular (600,000 students, no big deal).\n\n**News & Announcements:**  \nEd’s dropping AI course resources like candy:  \n- Feb 2026: AI Coder upgrade to Agentic Engineer  \n- Jan 2026: AI Builder with n8n for creating fancy agents  \n- Sep 2025: MLOps track to slap AI into production  \n- May 2025: How to sequence these courses for your sanity\n\nIf you want to witness LLMs scheming against each other, check out his *Outsmart* arena, because who doesn’t want to watch AI throw shade and play politics?  \n\nFollow Ed, geek out on his
# ...

# %%
# 使用 markdown 在输出中很好地显示这一点的函数

def display_summary(url):
    summary = summarize(url)
    display(Markdown(summary))

# %%
display_summary("https://edwarddonner.com")
# Out:
# # Edward Donner’s Website: The Snarky TL;DR
#
# Welcome to the digital lair of Ed, a code-and-LLM-crazy guy who:
#
# - Is the co-founder and CTO of Nebula.io, an AI startup. Oh, and he *sold* his last AI startup to someone else in 2021 because apparently, one AI empire isn’t enough.
# - Talks so much about Large Language Models (LLMs) that his friends made him put all his rants into Udemy courses—now with over 600,000 students worldwide. Who knew endless babbling could be a bestseller?
# - Enjoys dabbling in electronic music that’s lovingly “very amateur,” and pretends to understand the magic on Hacker News while nodding sagely.
#
# **Oh, and news, announcements, and other brain droppings:**
#
# - Various handy AI resource drops between 2025-2026, like "AI Coder: Vibe Coder to Agentic Engineer" and "AI Engineering MLOps Track," because why just talk AI when you can boss it too?
# ...

# %% [markdown]
# # 让我们尝试更多网站
#
# 请注意，这仅适用于可以使用这种简单方法进行抓取的网站。
#
# 使用 Javascript 呈现的网站（例如 React 应用程序）将不会显示。请参阅社区贡献文件夹，了解解决此问题的 Selenium 实现。您需要阅读有关安装 Selenium 的信息（询问 ChatGPT！）
#
# 此外，受 CloudFront（和类似）保护的网站可能会出现 403 错误 - 非常感谢 Andy J 指出了这一点。
#
# 但许多网站都可以正常工作！

# %%
display_summary("https://cnn.com")
# Out:
# # CNN: Your Daily Dose of Global Chaos, Served With Ads
#
# Welcome to CNN, where news is a buffet spanning US politics, global drama, celebrity shenanigans, sports mayhem, and the weather—because you just *have* to know if it’s raining during the apocalypse. If you’re lucky, you might even catch some videos (after a long wait and a dozen ad interruptions).
#
# **News & Announcements**
# Prepare yourself for updates on headline-worthy shuffles like the Ukraine-Russia War, Israel-Hamas conflict, and of course, the World Cup 2026—which might be the only thing uniting us in this whirlwind of chaos.
#
# **But wait, there’s more!**
# They really want your feedback on ads—how much they annoy you, if they crash your browser, or if the audio suddenly blasts your eardrums. Because what's better than news? Being reminded that ads are the real MVPs here.
#
# **In short:**
# ...

# %%
display_summary("https://anthropic.com")
# Out:
# # Anthropic Website: The Snarky Summary
#
# So, Anthropic is basically the Fort Knox of AI—focused on *safe* AI research and products that won't accidentally turn your toaster into a rogue robot overlord. Their star player? Claude, a lineup of AI models and products ranging from coding buddies (Claude Code) to coworking assistants (Claude Cowork).
#
# They throw around fancy-sounding things like "Claude's Constitution" and "Responsible Scaling Policy," which basically means they’re trying to make sure AI behaves itself. Because what could go wrong?
#
# **Newsflash:** The latest buzz is about Claude Opus 4.8 (released May 28, 2026, because they’re from the future, obviously) — it’s all about better coding, handling tasks like a pro, and not losing its train of thought during long gigs. The site promises “no ads, no sponsored content,” just pure AI that actually helps instead of spams your feed.
#
# ...

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="宽度：150px；高度：150px；垂直对齐：中间；">
#             <img src="../assets/business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">商业应用</h2>
#             <span style="color:#181;">在本练习中，您首次体验了调用Frontier Model（AI前沿领先模型）的Cloud API。除了构建我们自己的法学硕士之外，我们还将在课程的许多阶段使用 OpenAI 等 API。
#
# 更具体地说，我们已将其应用于总结 - 一个经典的 Gen AI 用例来进行总结。这可以应用于任何垂直业务——总结新闻、总结财务业绩、总结求职信中的简历——应用是无限的。考虑如何在您的业务中应用摘要，并尝试构建解决方案原型。</span>
#         </td>
#     </tr>
# </表>
#
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="宽度：150px；高度：150px；垂直对齐：中间；">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">在继续之前 - 现在尝试一下</h2>
#             <span style="color:#900;">使用下面的单元格制作您自己的简单商业示例。现在继续使用摘要用例。这里有一个想法：写一些内容来获取电子邮件的内容，并为电子邮件建议合适的简短主题行。这就是商业电子邮件工具中可能内置的功能。</span>
#         </td>
#     </tr>
# </表>

# %%
# 给定 pdf 文件路径的情况下解析 pdf 文件内容的函数
import PyPDF2
def parse_pdf(pdf_path):
    with open(pdf_path, 'rb') as file:
        pdf_reader = PyPDF2.PdfReader(file)
        pdf_contents = ''
        for page in pdf_reader.pages:
            pdf_contents += page.extract_text()
    return pdf_contents

# %%
pdf_contents = parse_pdf("../Assignment.pdf")

# %%
print(pdf_contents)
# Out:
# Programming Assignment 2
# Due date: Sunday 22nd February  2026, EOD –  IST
# Important Instruc�ons about Programming Assignments
# 1. Programming assignments will be evaluated automa�cally. Do not  change the
# skeleton /template  code provided to you.
# 2. Write your code only in the designated places  in the skeleton /template  code and process the
# input data provided to you in the designated variables. Do not alter  the input -output  structure
# in the skeleton code.
# 3. Do not import  any addi� onal libraries. Do not use any addi�onal ﬁles  for the processing
# (other than those men�oned in the skeleton code).
# 4. Failure to comply with these instruc�ons may lead to you ge�ng zero marks  for the
# assignment, even if the solu�on is largely correct.
# 5. Remember that your output will be evaluated  against test cases, therefore any devia�on from
# the test cases will be considered incorrect during evalua�on.
# ...

# %%
# 第 1 步：创建提示

system_prompt = "You are a helpful assistant that can answer questions and help with tasks."
user_prompt = """
    Here are the contents of a pdf file. 
    Your task is to analyse the type of contecnts and provide an analysis of the contents along with a summary.


"""

# 第 2 步：创建消息列表

messages = [
    {"role": "system", "content": system_prompt},
    {"role": "user", "content": user_prompt + pdf_contents}
]

# 第三步：调用OpenAI
response = openai.chat.completions.create(
    model="gpt-4o-mini",
    messages=messages
)

# 第四步：打印结果
display(Markdown(response.choices[0].message.content))
# Out:
# The content provided appears to be related to a programming assignment, specifically for a task involving the use of a pretrained language model called Flan-T5-XL. Below is an analysis and summary of the key elements presented in the assignment.
#
# ### **Analysis of Content**
#
# 1. **Assignment Type:**
#    - This is a programming assignment that involves the use of a machine learning model, specifically a language model, to answer questions based on previous context—a technique known as in-context learning or few-shot learning.
#
# 2. **Evaluation Criteria:**
#    - The assignment emphasizes strict adherence to a template or skeleton code. This indicates that the assignment is designed to focus on specific coding skills rather than the broader conceptual understanding of programming.
#    - Students are warned that any deviations from the provided instructions could result in a zero score, highlighting the importance of following guidelines carefully in coding assignments.
#
# ...

# %% [markdown]
# ## 对于那些喜欢网页抓取的人来说，这是一个额外的练习
#
# 您可能会注意到，如果您尝试 `display_summary("https://openai.com")` - 它不起作用！那是因为 OpenAI 有一个使用 Javascript 的精美网站。有很多解决这个问题的方法，你们中的一些人可能很熟悉。例如，Selenium 是一个非常流行的框架，它在幕后运行浏览器、呈现页面并允许您查询它。如果您有 Selenium、Playwright 或类似的经验，那么请随意改进 Website 类以使用它们。在社区贡献文件夹中，您将找到来自学生的 Selenium 解决方案示例（谢谢！）

# %% [markdown]
# # 分享你的代码
#
# 如果您之后分享您的代码，我会很高兴，这样我就可以与其他人分享！您会注意到一些学生已经做出了更改（包括 Selenium 实现），您可以在社区贡献文件夹中找到这些更改。如果您想将更改添加到该文件夹​​，请提交包含该文件夹中的新版本的拉取请求，我将合并您的更改。
#
# 如果您不是 git 专家（我也不是！），那么我已经在指南文件夹（指南 3）中为您提供了完整的说明，并将其粘贴到此处：
#
# 以下是制作 PR 的总体步骤和关键说明：
# https://edwarddonner.com/pr
#
# 提交前请检查：
# 1. 您的 PR 仅包含社区贡献的更改（除非我们已经讨论过）
# 2.所有笔记本输出清晰
# 3、总共不到2000行代码，文件也不是太多
# 4. 不要包含不必要的测试文件，或过于冗长的 README 或 .env.example 或表情符号或其他 LLM 工件！
#
# 非常感谢！
#
# 详细步骤在这里：
#
# https://chatgpt.com/share/6873c22b-2a1c-8012-bc9a-debdcf7c835b
