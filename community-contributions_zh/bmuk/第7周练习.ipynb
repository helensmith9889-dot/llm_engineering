# %% [markdown]
# # 第 7 周练习
#
# ## 练习目标（理念）
#
# 本笔记本目前是**占位草稿**：作者标注会围绕 **QLoRA / 微调（Fine-tuning）** 展开，但仓库里尚未放入可运行的代码单元格。
#
# 第 7 周常见练习形态（对照课程与其他同学作业）包括：
#
# - 用 **4-bit 量化**（如 `BitsAndBytesConfig` + NF4）加载 Llama 等基座模型
# - 配置 **LoRA / QLoRA**（`LoraConfig` + `SFTTrainer` 或加载现成 `PeftModel`）
# - 在商品价格等任务上做训练或推理，并用误差 / 命中率评估
#
# ## 和本课 Week 7 的关系
#
# | 本课概念 | 你之后补代码时通常会看到 |
# |----------|--------------------------|
# | 量化省显存 | `load_in_4bit=True` |
# | 低秩适配器 | `r` / `lora_alpha` / `target_modules` |
# | 监督微调 | prompt + completion → `text` 字段 |
# | 评估 | 解析 `Price is $...` 或自定义指标 |
#
# ## 怎么跑
#
# 当前仅有本说明格，**没有可执行代码**。若你要完成本周练习，请自行追加代码单元格（或参考同目录其他同学的「第7周练习」完整流水线），并配置 HuggingFace / GPU 环境后再从上到下运行。
#
# （详见你后续补上的代码单元格中的中文旁注。）
