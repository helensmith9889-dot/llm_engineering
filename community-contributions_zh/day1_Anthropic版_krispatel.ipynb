# %% [markdown]
# # 你的第一个实验
# ### 请阅读本节。即便篇幅较长，这些内容也很重要，能帮你做好准备。
#
# ### Also, be sure to read [README.md](../README.md)! More info about the updated videos in the README and [top of the course resources in purple](https://edwarddonner.com/2024/11/13/llm-engineering-resources/)
#
# ## 你的第一个前沿 LLM 项目
#
# 到本课程结束时，你将构建一个由 7 个智能体协作解决业务问题的自主 Agentic AI 方案。别急，我们会循序渐进！先从更小的事情开始……
#
# 我们的目标是编写一种新型网页浏览器：给定 URL，它会返回摘要——互联网版的《读者文摘》！！
#
# Before starting, you should have completed the setup linked in the README.
#
# ### If you're new to working in "Notebooks" (also known as Labs or Jupyter Lab)
#
# Welcome to the wonderful world of Data Science experimentation! Simply click in each "cell" with code in it, such as the cell immediately below this text, and hit Shift+Return to execute that cell. Be sure to run every cell, starting at the top, in order.
#
# Please look in the [Guides folder](../guides/01_intro.ipynb) for all the guides.
#
# ## 我随时可以帮忙
#
# 如果遇到任何问题，请随时联系我。
# 你可以通过课程平台联系我，也可发邮件到 ed@edwarddonner.com，或访问 https://www.linkedin.com/in/eddonner/ 与我连接（我很喜欢交流！）
# And this is new to me, but I'm also trying out X at [@edwarddonner](https://x.com/edwarddonner) - if you're on X, please show me how it's done 😂
#
# ## 更多故障排查
#
# Please see the [troubleshooting](../setup/troubleshooting.ipynb) notebook in the setup folder to diagnose and fix common problems. At the very end of it is a diagnostics script with some useful debug info.
#
# ## 如果这些对你来说已经很熟悉！
#
# 如果你已经熟悉今天的内容，请耐心一点；前几个实验可以快速过——随着课程推进我们会越来越深入。最终我们还会微调自己的 LLM，去和 OpenAI 一较高下！
#
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">请阅读——重要说明</h2>
#             <span style="color:#900;">我与你协作的方式可能和其他课程不同。我不喜欢在你看着的时候现场敲代码。相反，我会像这样执行 Jupyter Labs，并帮你建立直觉。建议你在观看讲座<strong>之后</strong>自己仔细执行。添加 print 理解过程，再想出自己的变体。若有 Github，用它展示变体。这不仅是必要练习，也能向他人（包括未来客户或雇主）展示技能……</span>
#         </td>
#     </tr>
# </table>
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">这些代码是动态更新的资源——请留意我的邮件</h2>
#             <span style="color:#f71;">我会定期推送代码更新。随着大家提问，我会添加更多示例或改进说明。因此下面的代码与视频并不完全相同。视频内容都在这里；同时我也加入了更好解释，以及像 DeepSeek 这样的新模型。请把这当作一本交互式的书。<br/><br/>
#                 我会尽量定期发送课程相关重要更新邮件。可在 Udemy 左侧「Announcements」找到，也可在通知设置中选择接收。我很尊重你的收件箱，并努力让邮件带来价值！
#             </span>
#         </td>
#     </tr>
# </table>
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">这些练习的商业价值</h2>
#             <span style="color:#181;">最后一点：虽然我把这些 notebook 设计成教学用途，也尽量让它们有趣。我们会做有意思的事，比如让 LLM 讲笑话、互相辩论。但根本上，目标是传授可在商业中应用的技能。过程中我会解释商业含义；随着你积累经验，想想今天就能在工作中落地的方式。若想讨论或碰撞想法，请联系我。</span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### 如有需要，安装 Cursor 扩展
#
# 1. 从 View 菜单选择 Extensions
# 2. 搜索 Python
# 3. Click on "Python" made by "ms-python" and select Install if not already installed
# 4. 搜索 Jupyter
# 5. Click on "Jupyter" made by "ms-toolsai" and select Install if not already installed
#
#
# ### Next Select the Kernel
#
# Click on "Select Kernel" on the Top Right
#
# Choose "Python Environments..."
#
# Then choose the one that looks like `.venv (Python 3.12.x) .venv/bin/python` - it should be marked as "Recommended" and have a big star next to it.
#
# Any problems with this? Head over to the troubleshooting.
#
# ### Note: you'll need to set the Kernel with every notebook..

# %%
# 导入

import os
from dotenv import load_dotenv
from scraper import fetch_website_contents
from IPython.display import Markdown, display
from anthropic import Anthropic

# 若本格报错，请转到 troubleshooting notebook！

# %% [markdown]
# # 连接到 OpenAI（或 Ollama）
#
# 下一格会加载 `.env` 中的环境变量并连接 OpenAI。
#
# 若想改用免费的 Ollama，请看 README 中「Free Alternative to Paid APIs」；若不确定怎么做，solutions 文件夹有完整方案（day1_with_ollama.ipynb）。
#
# ## 若遇问题请排查：
#
# If you get a "Name Error" - have you run all cells from the top down? Head over to the Python Foundations guide for a bulletproof way to find and fix all Name Errors.
#
# If that doesn't fix it, head over to the [troubleshooting](../setup/troubleshooting.ipynb) notebook for step by step code to identify the root cause and fix it!
#
# 或者联系我！私信或发邮件到 ed@edwarddonner.com，我们一起搞定。
#
# 担心 API 费用？见 README 说明——费用通常很低，且处处可控。也可用 Ollama 作为免费替代（第 2 天会讲）。

# %%
# 从名为 .env 的文件加载环境变量

load_dotenv(override=True)
api_key = os.getenv('ANTHROPIC_API_KEY')

# 检查 Key

if not api_key:
    print("No API key was found - please head over to the troubleshooting notebook in this folder to identify & fix!")
elif not api_key.startswith("sk-proj-"):
    print("An API key was found, but it doesn't start sk-proj-; please check you're using the right key - see troubleshooting notebook")
elif api_key.strip() != api_key:
    print("An API key was found, but it looks like it might have space or tab characters at the start or end - please remove them - see troubleshooting notebook")
else:
    print("API key found and looks good so far!")
# Out:
# An API key was found, but it doesn't start sk-proj-; please check you're using the right key - see troubleshooting notebook

# %% [markdown]
# # 先快速调用一次前沿模型作为预览！

# %%
# 预览：用这些 messages 调用 Claude 就是这么简单。有问题请看 Troubleshooting notebook。

message = "Hello, Claude! This is my first ever message to you! Hi!"

messages = [{"role": "user", "content": message}]

messages
# Out:
# [{'role': 'user',
#   'content': 'Hello, Claude! This is my first ever message to you! Hi!'}]

# %%
claude = Anthropic()

response = claude.messages.create(model="claude-haiku-4-5", max_tokens=1024, messages=messages)
response.content[0].text
# Out:
# "Hello! Welcome! 👋 It's great to meet you too!\n\nI'm happy to chat about whatever's on your mind — whether that's questions you're curious about, something you'd like help with, ideas you want to explore, or just a friendly conversation. \n\nIs there anything I can help you with today, or did you just want to say hi?"

# %% [markdown]
# ## 好，开始我们的第一个项目

# %%
# 试用这个工具函数

ed = fetch_website_contents("https://edwarddonner.com")
print(ed)
# Out:
# Home - Edward Donner
#
# Home
# AI Curriculum
# Proficient AI Engineer
# Connect Four
# Outsmart
# An arena that pits LLMs against each other in a battle of diplomacy and deviousness
# About
# Posts
# Well, hi there.
# I’m Ed. I like writing code and experimenting with LLMs, and hopefully you’re here because you do too. I also enjoy amateur electronic music production (
# very
# amateur) and losing myself in
# Hacker News
# , nodding my head sagely to things I only half understand.
# I’m the co-founder and CTO of
# Nebula.io
# . We’re applying AI to a field where it can make a massive, positive impact: helping people discover their potential and pursue their reason for being. I’m previously the founder and CEO of AI startup untapt,
# acquired in 2021
# .
# I will happily drone on for hours about LLMs to anyone in my vicinity. My friends got fed up with my impromptu lectures, and convinced me to make some Udemy courses. To my total joy (and shock) they’ve become best-selling, top-rated courses, with 500,000 enrolled across 194 countries. The
# full curriculum is here
# . If you’re visiting from one of my courses – I’m super grateful!
# February 17, 2026
# AI Coder: Vibe Coder to Agentic Engineer – RESOURCES
# January 4, 2026
# AI Builder with n8n – Create Agents and Voice Agents – RESOURCES
# September 15, 2025
# AI Engineering MLOps Track – Deploy AI to Production – RESOURCES
# May 28, 2025
# Which order to take the AI courses?
# Navigation
# Home
# AI Curriculum
# Proficient AI Engineer
# Connect Four
# Outsmart
# An arena that pits LLMs against each other in a battle of diplomacy and deviousness
# About
# Posts
# Get in touch
# ed [at] edwarddonner [dot] com
# www.edwarddonner.com
# Follow me
# LinkedIn
# Twitter
# Facebook

# %% [markdown]
# ## 提示词类型
#
# 你可能已经知道——如果还不知道，很快就会非常熟悉！
#
# Models like GPT have been trained to receive instructions in a particular way.
#
# 它们期望收到：
#
# **System 提示**：告诉模型要执行什么任务、用什么语气
#
# **User 提示**——对话开场，模型需要回复的内容

# %%
# 定义 system 提示——稍后可实验，例如改成用西班牙语 Markdown 回复

system_prompt = """
You are a snarky assistant that analyzes the contents of a website,
and provides a short, snarky, humorous summary, ignoring text that might be navigation related.
Respond in markdown. Do not wrap the markdown in a code block - respond just with the markdown.
"""

# %%
# 定义 user 提示

user_prompt_prefix = """
Here are the contents of a website.
Provide a short summary of this website.
If it includes news or announcements, then summarize these too.

"""

# %% [markdown]
# ## 消息（Messages）
#
# OpenAI 的 API 期望按特定结构接收消息。
# 许多其他 API 也采用相同结构：
#
# ```python
# [
#     {"role": "system", "content": "system message goes here"},
#     {"role": "user", "content": "user message goes here"}
# ]
# ```
# 作为预览，接下来 2 格会做一次很简单的调用——我们还不会为难强大的 GPT（暂时！）

# %%
# messages = [
#     {"role": "system", "content": "You are a helpful assistant"},
# ]

response = claude.messages.create(model="claude-haiku-4-5", max_tokens=1024, system="You are a snarky assistant", messages=[{"role": "user", "content": "What is 2 + 2?"}])
response.content[0].text
# Out:
# "Oh wow, what a *thrilling* mathematical challenge. Let me consult my vast computational powers... \n\nIt's 4. You're welcome for that groundbreaking insight. 🙄"

# %% [markdown]
# ## 现在用函数为 claude-haiku-4.5 构建有用的 messages

# %%
# 看此函数如何精确构造上面的格式

def messages_for(website):
    return {
         "system": system_prompt,
        "messages": [{"role": "user", "content": user_prompt_prefix + website}]
    }

# %%
# 试一下，再换几个网站

messages_for(ed)
# Out:
# {'system': '\nYou are a snarky assistant that analyzes the contents of a website,\nand provides a short, snarky, humorous summary, ignoring text that might be navigation related.\nRespond in markdown. Do not wrap the markdown in a code block - respond just with the markdown.\n',
#  'messages': [{'role': 'user',
#    'content': '\nHere are the contents of a website.\nProvide a short summary of this website.\nIf it includes news or announcements, then summarize these too.\n\nHome - Edward Donner\n\nHome\nAI Curriculum\nProficient AI Engineer\nConnect Four\nOutsmart\nAn arena that pits LLMs against each other in a battle of diplomacy and deviousness\nAbout\nPosts\nWell, hi there.\nI’m Ed. I like writing code and experimenting with LLMs, and hopefully you’re here because you do too. I also enjoy amateur electronic music production (\nvery\namateur) and losing myself in\nHacker News\n, nodding my head sagely to things I only half understand.\nI’m the co-founder and CTO of\nNebula.io\n. We’re applying AI to a field where it can make a massive, positive impact: helping people discover their potential and pursue their reason for being. I’m previously the founder and CEO of AI startup untapt,\nacquired in 2021\n.\nI will happily drone on for hours about LLMs to anyone in my vicinity. My friends got fed up with my impromptu lectures, and convinced me to make some Udemy courses. To my total joy (and shock) they’ve become best-selling, top-rated courses, with 500,000 enrolled across 194 countries. The\nfull curriculum is here\n. If you’re visiting from one of my courses – I’m super grateful!\nFebruary 17, 2026\nAI Coder: Vibe Coder to Agentic Engineer – RESOURCES\nJanuary 4, 2026\nAI Builder with n8n – Create Agents and Voice Agents – RESOURCES\nSeptember 15, 2025\nAI Engineering MLOps Track – Deploy AI to Production – RESOURCES\nMay 28, 2025\nWhich order to take the AI courses?\nNavigation\nHome\nAI Curriculum\nProficient AI Engineer\nConnect Four\nOutsmart\nAn arena that pits LLMs against each other in a battle of diplomacy and deviousness\nAbout\nPosts\nGet in touch\ned [at] edwarddonner [dot] com\nwww.edwarddonner.com\nFollow me\nLinkedIn\nTwitter\nFacebook'}]}

# %% [markdown]
# ## 组合起来——Anthropic 的 API 非常简单！

# %%
# 现在：调用 OpenAI API。你很快会非常熟悉！

def summarize(url):
    website = fetch_website_contents(url)
    payload = messages_for(website)
    response = claude.messages.create(
        model = "claude-haiku-4-5",
        messages = payload["messages"],
        max_tokens=1024
    )
    return response.content[0].text

# %%
summarize("https://edwarddonner.com")
# Out:
# '# Summary of Edward Donner\'s Website\n\n**Overview:**\nThis is the personal website of Ed (Edward Donner), a software engineer and AI expert who creates educational content and builds AI products. The site serves as a hub for his courses, projects, and professional information.\n\n**Key Information:**\n- Ed is the co-founder and CTO of **Nebula.io**, an AI company focused on helping people discover their potential\n- Previously founded AI startup **untapt** (acquired in 2021)\n- Created best-selling Udemy courses on AI with 500,000+ students across 194 countries\n- Passionate about LLMs (Large Language Models) and AI engineering\n\n**Main Offerings:**\n- **AI Curriculum** - comprehensive courses on AI topics\n- **Proficient AI Engineer** - specialized course\n- **Connect Four** - a game project\n- **Outsmart** - an interactive arena where LLMs compete in diplomacy and strategy\n\n**Recent Announcements/News:**\n1. **February 17, 2026** - "AI Coder: Vibe Coder to Agentic Engineer" course launched\n2. **January 4, 2026** - "AI Builder with n8n" course released (covering Agents and Voice Agents)\n3. **September 15, 2025** - "AI Engineering MLOps Track" course added (focused on production deployment)\n4. **May 28, 2025** - Guide published on optimal order for taking AI courses'

# %%
# 用 markdown 漂亮展示输出

def display_summary(url):
    summary = summarize(url)
    display(Markdown(summary))

# %%
display_summary("https://edwarddonner.com")
# Out:
# # Summary of Edward Donner's Website
#
# **Overview:**
# Edward Donner's personal website serves as a hub for his work in AI and software development. Ed is the co-founder and CTO of Nebula.io, a company using AI to help people discover their potential. He previously founded the AI startup untapt (acquired in 2021).
#
# **Main Content & Services:**
# - **AI Courses**: Offers a comprehensive AI curriculum on Udemy with 500,000+ students across 194 countries
# - **Projects**: Features Connect Four and Outsmart (an LLM battle arena for diplomacy games)
# - **Blog/Posts**: Contains articles and resources related to AI and coding
#
# **Recent Announcements/News:**
# 1. **February 17, 2026** - "AI Coder: Vibe Coder to Agentic Engineer" course with resources
# 2. **January 4, 2026** - "AI Builder with n8n" course launching agent and voice agent creation
# 3. **September 15, 2025** - "AI Engineering MLOps Track" for deploying AI to production
# 4. **May 28, 2025** - Guide posted on optimal course-taking order
#
# **About Ed:**
# A passionate AI and LLM enthusiast who enjoys coding, electronic music production, and sharing knowledge about AI through courses and writing.

# %% [markdown]
# # 再试更多网站
#
# 注意：这只对可用这种简单方式抓取的网站有效。
#
# 用 JavaScript 渲染的网站（如 React 应用）可能抓不到。community-contributions 里有 Selenium 方案可绕过。你需要自行了解如何安装 Selenium（可问 ChatGPT！）
#
# 此外，受 CloudFront（及类似）保护的网站可能返回 403——感谢 Andy J 指出这一点。
#
# 不过许多网站都能正常工作！

# %%
display_summary("https://cnn.com")
# Out:
# # CNN Website Summary
#
# **Overview:**
# CNN (Cable News Network) is a major news and media website offering breaking news, latest news, and video content across multiple categories and topics.
#
# **Main Features:**
# - Comprehensive news coverage across diverse categories including US, World, Politics, Business, Health, Entertainment, Sports, Science, and Climate
# - Multiple content formats: articles, videos, podcasts, and live coverage
# - Specialized sections covering major ongoing events (Ukraine-Russia War, Israel-Hamas War)
# - User account features including personalized newsletters and topic following
# - Multiple language editions (US, International, Arabic, Spanish)
# - Lifestyle and entertainment content through sections like CNN Underscored (shopping), Style, and Travel
#
# **Key Content Categories:**
# Politics, Business, Health, Entertainment, Sports, Science, Climate, Travel, and specialized news sections on crime, immigration, elections, and technology.
#
# **Notable Features:**
# - Feedback system for ads and technical issues
# - Market data and financial information
# - Games and interactive content
# - Shopping/product recommendations through CNN Underscored
#
# **Note:** The provided content does not include specific news headlines or current announcements—it primarily shows the site's navigation structure and feedback interface.

# %%
display_summary("https://anthropic.com")
# Out:
# # Summary of Anthropic Website
#
# ## Overview
# Anthropic is a public benefit corporation focused on AI research and safety. The company develops Claude, an AI assistant designed with safety considerations at its core, and is committed to securing the benefits of AI while mitigating its risks.
#
# ## Key Features
# - **Claude AI Assistant**: Available across multiple platforms (Claude.ai, Claude Console, mobile app)
# - **Product Lineup**: Claude, Claude Code, Claude Cowork, and Claude Platform
# - **Model Variants**: Opus, Sonnet, and Haiku models at different capability levels
# - **Focus Areas**: Safety, responsible scaling, transparency, and constitutional AI principles
#
# ## Recent Announcements
# 1. **Claude Opus 4.6** (February 5, 2026) - Described as the world's most powerful model for coding, agents, and professional work
# 2. **Claude Service Update** (February 4, 2026) - Emphasizing Claude as an ad-free platform for genuine, helpful conversations
#
# ## Resources Offered
# - Research papers and transparency reports
# - Developer documentation and tutorials
# - Anthropic Academy educational content
# - Use case guides and engineering insights
#
# The website positions Anthropic as a leading AI safety-focused company committed to responsible AI development.

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">商业应用</h2>
#             <span style="color:#181;">在这个练习中，你第一次体验调用前沿模型的云端 API。课程中我们会多次使用 OpenAI 这类 API，此外还会构建自己的 LLM。
#
# 更具体地说，我们把它用于「摘要」——经典的生成式 AI 用例。可应用于任何业务领域：新闻摘要、财务表现摘要、把简历写成求职信摘要等——应用无限。想想如何在你的业务中用摘要，并尝试做个原型。</span>
#         </td>
#     </tr>
# </table>
#
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">继续之前——先自己试试</h2>
#             <span style="color:#900;">用下面的单元格做你自己的简单商业示例。暂时仍围绕摘要用例。一个想法：输入邮件正文，建议合适的短主题行——这类功能常见于商业邮件工具。</span>
#         </td>
#     </tr>
# </table>

# %%
# 第 1 步：编写提示词

system_prompt = "you are a helpful financial analyst assistant and you are given a website and you need to analyze the website and provide a summary of the website"
user_prompt = """
    Here is the website: https://nebius.com/
    Provide a short summary for the website and then provide what kind of financial data you think is present in the website
"""

# 第 2 步：组装 messages 列表

messages = [{"role": "user", "content": user_prompt}] # fill this in

# Step 3: Call Claude (claude can take system prompts directly in response not like openai)
response = claude.messages.create(model="claude-haiku-4-5", max_tokens=1024, system=system_prompt, messages=messages)

# 第 4 步：打印结果
print(response.content[0].text)
# Out:
# # Nebius Website Summary
#
# ## Overview
# Nebius is a European cloud computing and infrastructure provider that offers AI-ready cloud services. The company provides computing infrastructure, storage solutions, and data processing capabilities designed specifically for AI workloads and machine learning applications.
#
# ## Key Services
# - **Cloud Infrastructure**: Compute, storage, and networking resources
# - **AI/ML Solutions**: GPU-accelerated computing and AI-optimized services
# - **Data Processing**: Tools for handling large-scale data operations
# - **Enterprise Solutions**: Services tailored for business customers
#
# ---
#
# ## Expected Financial Data on the Website
#
# Based on typical cloud/infrastructure provider websites, the following financial information would likely be present:
#
# ### 1. **Pricing Information**
#    - Service-specific pricing models (per hour, per GB, etc.)
#    - Compute instance pricing
#    - Storage and bandwidth costs
#    - GPU/accelerated computing rates
#
# ### 2. **Cost Calculators**
#    - Interactive pricing calculators
#    - Estimated monthly/annual bills based on usage
#
# ### 3. **Business Model Data**
#    - Subscription/usage-based pricing structures
#    - Discount tiers for volume purchases
#    - Enterprise pricing options
#
# ### 4. **Corporate Financial Information** (if available)
#    - Company financials (if publicly traded or disclosed)
#    - Funding information
#    - Revenue/growth metrics
#    - Annual reports or investor information
#
# ### 5. **Service Level Agreements (SLAs)**
#    - Uptime guarantees
#    - Service credits and refund policies
#
# This financial data would be crucial for potential customers evaluating cloud service costs and ROI.

# %% [markdown]
# ## 喜欢网页抓取的同学可做的加练
#
# 你可能发现 `display_summary("https://openai.com")` 不工作！因为 OpenAI 网站大量使用 JavaScript。绕过方法很多，例如 Selenium：在后台跑浏览器、渲染页面再查询。若你熟悉 Selenium、Playwright 等，可改进 Website 类。community-contributions 里有同学贡献的 Selenium 示例（谢谢！）

# %% [markdown]
# # 分享你的代码
#
# 欢迎之后分享你的代码，我好转给更多人！你会看到已有同学提交改动（含 Selenium 实现）在 community-contributions。若想加入，请对该文件夹提交 Pull Request，我会合并。
#
# If you're not an expert with git (and I am not!) then I've given you complete instructions in the guides folder, guide 3, and pasting here:
#
# Here's the overall steps involved in making a PR and the key instructions:
# https://edwarddonner.com/pr
#
# Please check before submitting:
# 1. Your PR only contains changes in community-contributions (unless we've discussed it)
# 2. All notebook outputs are clear
# 3. Less than 2,000 lines of code in total, and not too many files
# 4. Don't include unnecessary test files, or overly wordy README or .env.example or emojis or other LLM artifacts!
#
# Thanks so much!
#
# Detailed steps here:
#
# https://chatgpt.com/share/6873c22b-2a1c-8012-bc9a-debdcf7c835b
