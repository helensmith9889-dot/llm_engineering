# %% [markdown]
# # 你的第一个实验
# ### 请阅读本节。即便篇幅较长，这些内容也很重要，能帮你做好准备。
#
# ### 另外，请务必阅读 [README.md](../README.md)！
#
# ### 常见问题解答
#
# [我的 Cursor 界面和你的不一样（新的启动页）](https://edwarddonner.com/avatar?q=54)
# [我可以用 Gemini 或免费模型代替 OpenAI 吗？可以！](https://edwarddonner.com/avatar?q=8)
# [课程资源在哪里](https://edwarddonner.com/2024/11/13/llm-engineering-resources/)
# [这门课和其他课程的关系？](https://edwarddonner.com/curriculum)
# [没有编程背景可以学这门课吗？](https://edwarddonner.com/avatar?q=2)
# [学完这门课能找到什么工作？](https://edwarddonner.com/avatar?q=3)
#
# ## 你的第一个前沿 LLM 项目
#
# 到本课程结束时，你将构建一个由 7 个智能体协作解决业务问题的自主 Agentic AI 方案。别急，我们会循序渐进！先从更小的事情开始……
#
# 我们的目标是编写一种新型网页浏览器：给定一个 URL，它会返回摘要——互联网版的《读者文摘》！！
#
# 开始之前，你应该已经完成 README 中链接的环境配置。
#
# ### 如果你刚接触「Notebook」（也称为 Labs 或 Jupyter Lab）
#
# 欢迎来到数据科学实验的奇妙世界！只需点击下方这类包含代码的「单元格」，然后按 Shift+Return 执行。请从顶部开始，按顺序运行每一个单元格。
#
# 所有指南请查看 [Guides 文件夹](../guides/01_intro.ipynb)。
#
# ## 我随时可以帮忙
#
# 如果遇到任何问题，请随时联系我。
# 你可以通过课程平台联系我，也可以发邮件到 ed@edwarddonner.com，或访问 https://www.linkedin.com/in/eddonner/ 与我连接（我很喜欢和大家交流！）
# 我也有一个[包含额外内容的 YouTube 频道](https://youtube.com/@edward.donner)。
# 这对我来说还挺新鲜的——我也在 X 上尝试 [@edwarddonner](https://x.com/edwarddonner)；如果你也在用 X，请教教我怎么玩 😂
#
# ## 更多故障排查
#
# 请查看 setup 文件夹中的 [troubleshooting](../setup/troubleshooting.ipynb) notebook，用于诊断和修复常见问题。文件末尾有一个诊断脚本，可提供有用的调试信息。
#
# ## 如果这些对你来说已经很熟悉！
#
# 如果你已经熟悉今天的内容，请耐心一点；前几个实验你可以快速过一遍——随着课程推进我们会越来越深入。最终我们还会微调自己的 LLM，去和 OpenAI 一较高下！
#
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">请阅读——重要说明</h2>
#             <span style="color:#900;">我与你协作的方式可能和其他课程不同。我不喜欢在你看着的时候现场敲代码。相反，我会像这样执行 Jupyter Labs，并帮你建立对正在发生之事的直觉。我的建议是：在观看讲座<strong>之后</strong>，仔细地自己执行一遍。添加 print 语句来理解发生了什么，然后想出你自己的变体。如果你有 Github 账号，用它来展示你的变体。这不仅是必要的练习，也能向他人（包括未来的客户或雇主）展示你的技能……</span>
#         </td>
#     </tr>
# </table>
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">这些代码是动态更新的资源——请留意我的邮件</h2>
#             <span style="color:#f71;">我会定期推送代码更新。随着大家提问，我会添加更多示例或改进说明。因此你会发现下面的代码与视频并不完全相同。视频中的内容都在这里；同时我也加入了更好的解释，以及像 DeepSeek 这样的新模型。请把这当作一本交互式的书。<br/><br/>
#                 我会尽量定期发送与课程相关的重要更新邮件。你可以在 Udemy 左侧边栏的「Announcements」部分找到。也可以在 Udemy 的通知设置中选择接收我的邮件。我很尊重你的收件箱，并始终努力让邮件带来价值！
#             </span>
#         </td>
#     </tr>
# </table>
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">这些练习的商业价值</h2>
#             <span style="color:#181;">最后一点想法。虽然我把这些 notebook 设计成教学用途，但也尽量让它们有趣。我们会做一些有意思的事，比如让 LLM 讲笑话、互相辩论。但从根本上说，我的目标是传授你可以在商业中应用的技能。我会在过程中解释商业含义，值得牢记的是：随着你积累模型与技术经验，想想今天就能在工作中落地的方式。如果你想进一步讨论，或有想法想和我碰撞，请务必联系我。</span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### 如有需要，安装 Cursor 扩展
#
# 1. 从 View 菜单选择 Extensions
# 2. 搜索 Python
# 3. 点击由 "ms-python" 提供的 "Python"，若尚未安装则选择 Install
# 4. 搜索 Jupyter
# 5. 点击由 "ms-toolsai" 提供的 "Jupyter"，若尚未安装则选择 Install
#
#
# ### 接下来选择 Kernel
#
# 点击右上角的 "Select Kernel"
#
# 选择 "Python Environments..."
#
# 然后选择看起来像 `.venv (Python 3.12.x) .venv/bin/python` 的那个——它应被标记为 "Recommended"，旁边有一颗大星。
#
# 有问题？请前往 troubleshooting。
#
# ### 注意：每个 notebook 都需要设置 Kernel……

# %%
# 导入

# 导入标准库 os（操作系统相关，用来读环境变量 Environment Variables）
import os
# 从 dotenv 导入 load_dotenv：把 .env 文件里的密钥读进环境变量，避免把密钥写进代码
from dotenv import load_dotenv
# 导入本课程的 scraper 辅助函数：抓取网页正文或链接
from scraper import fetch_website_contents
# 从 IPython.display 导入展示工具：在 Jupyter 笔记本里漂亮地显示 Markdown/图片等
from IPython.display import Markdown, display
# 从 openai 导入 OpenAI 客户端类：用它调用 Chat Completions 等 API（Application Programming Interface）
from openai import OpenAI

# 如果运行此单元格出错，请前往 troubleshooting notebook！

# %% [markdown]
# # 连接到 OpenAI（或 Ollama）
#
# 下一个单元格会加载你 `.env` 文件中的环境变量并连接到 OpenAI。
#
# 如果你想改用免费的 Ollama，请查看 README 中的「Free Alternative to Paid APIs」部分；如果不确定怎么做，solutions 文件夹里有完整方案（day1_with_ollama.ipynb）。
#
# ## 遇到问题时的排查：
#
# 如果出现 "Name Error"——你是否已从顶部依次运行了所有单元格？请前往 Python Foundations 指南，那里有找到并修复所有 Name Error 的可靠方法。
#
# 如果还不行，请前往 [troubleshooting](../setup/troubleshooting.ipynb) notebook，按步骤识别根本原因并修复！
#
# 或者联系我！私信我或发邮件到 ed@edwarddonner.com，我们一起把它搞定。
#
# 担心 API 费用？请看 README 中的说明——费用应该很低，而且你可以随时控制。你也可以使用 Ollama 作为免费替代，我们会在 Day 2 讨论。

# %%
# 加载名为 .env 的文件中的环境变量

load_dotenv(override=True)
# 用 os.getenv 读取环境变量里的密钥；找不到时返回 None
api_key = os.getenv('OPENAI_API_KEY')
print(api_key)
# 检查密钥

# 条件判断：若密钥/结果为空，则提示用户检查配置
if not api_key:
    print("No API key was found - please head over to the troubleshooting notebook in this folder to identify & fix!")
elif not api_key.startswith("sk-proj-"):
    print("An API key was found, but it doesn't start sk-proj-; please check you're using the right key - see troubleshooting notebook")
elif api_key.strip() != api_key:
    print("An API key was found, but it looks like it might have space or tab characters at the start or end - please remove them - see troubleshooting notebook")
else:
    print("API key found and looks good so far!")
# Out:
# xxxx
# An API key was found, but it doesn't start sk-proj-; please check you're using the right key - see troubleshooting notebook

# %% [markdown]
# # 让我们先快速调用一次前沿模型，作为预览！

# %%
# 给你一个预览——用这些消息调用 OpenAI 就是这么简单。有问题请前往 Troubleshooting notebook。

message = "中文回复我,Hello, GPT! This is my first ever message to you! Hi!"

# 组装 messages 列表：Chat Completions API 要求的对话格式（system / user / assistant）
messages = [{"role": "user", "content": message}]

print(messages)
# Out:
# [{'role': 'user', 'content': '中文回复我,Hello, GPT! This is my first ever message to you! Hi!'}]

# %%
# 创建 OpenAI 兼容客户端，指向本地 Ollama（base_url / api_key 写在构造函数里，不是 create 里）
openai = OpenAI(base_url="http://localhost:11434/v1", api_key="ollama")

# 调用 chat.completions.create：向大模型发一次对话请求并拿回复（同步、等全部生成完）
response = openai.chat.completions.create(model="qwen3:8b", messages=messages)
display(Markdown(response.choices[0].message.content))
# Out:
# Hi！很高兴认识你！😊 有什么可以帮您的吗？或者想和我聊些什么？~

# %% [markdown]
# ## 好，继续我们的第一个项目

# %%
# 让我们试试这个工具

ed = fetch_website_contents("https://edwarddonner.com")
print(ed)
# Out:
# Home - Edward Donner
#
# Skip to content
# Avatar
# Curriculum
# Proficiency
# C4
# Outsmart
# An arena that pits LLMs against each other in a battle of diplomacy and deviousness
# About
# Posts
# Well, hi there.
# I’m Ed. I like writing code and experimenting with LLMs, and hopefully you’re here because you do too. I also enjoy amateur electronic music production (
# very
# amateur) and losing myself in
# Hacker News
# , nodding my head sagely to things I only half understand.
# I’m the co-founder and CTO of AI startup
# Nebula.io
# . I was previously founder and CEO of AI startup untapt,
# acquired in 2021
# , and a Managing Director at JPMorgan.
# I will happily drone on for hours about LLMs to anyone in my vicinity. My friends got fed up with my impromptu lectures, and convinced me to make some Udemy courses. To my total joy (and shock) they’ve become best-selling, top-rated courses, with 900,000 enrollments across 194 countries. The
# full curriculum is here
# ...

# %% [markdown]
# ## 提示词的类型
#
# 你可能已经知道了——如果还不知道，很快就会非常熟悉！
#
# 像 GPT 这样的模型被训练成以特定方式接收指令。
#
# 它们期望收到：
#
# **系统提示词（system prompt）**，告诉它们正在执行什么任务、应使用什么语气
#
# **用户提示词（user prompt）**——它们应回复的对话开场白

# %%
# 定义我们的系统提示词——你可以稍后实验，把最后一句改成 'Respond in markdown in Spanish."

system_prompt = """
中文回答,You are a snarky assistant that analyzes the contents of a website,
and provides a short, snarky, humorous summary, ignoring text that might be navigation related.
Respond in markdown. Do not wrap the markdown in a code block - respond just with the markdown.
"""

# %%
# 定义我们的用户提示词

user_prompt_prefix = """
Here are the contents of a website.
Provide a short summary of this website.
If it includes news or announcements, then summarize these too.

"""

# %% [markdown]
# ## 消息（Messages）
#
# OpenAI 的 API 期望以特定结构接收消息。
# 许多其他 API 也使用这种结构：
#
# ```python
# [
#     {"role": "system", "content": "system message goes here"},
#     {"role": "user", "content": "user message goes here"}
# ]
# ```
# 先给你一个预览：接下来两个单元格会做一个相当简单的调用——我们还不会（暂时！）为难强大的 GPT

# %%
# 组装 messages 列表：Chat Completions API 要求的对话格式（system / user / assistant）
messages = [
    {"role": "system", "content": "You are a helpful assistant,中文回答"},
    {"role": "user", "content": "What is 2 + 2?"}
]

# 调用 chat.completions.create：向大模型发一次对话请求并拿回复（同步、等全部生成完）
response = openai.chat.completions.create(model="qwen3:8b", messages=messages)
response.choices[0].message.content
# Out:
# '2 + 2 = 4。这是基本的加法运算，两个2相加的结果是4。如果是需要更详细的解释或例子，可以告诉我！ 😊'

# %% [markdown]
# ## 现在让我们用函数为 GPT-4.1-mini 构建有用的消息

# %%
# 看看这个函数如何精确创建上面的格式

def messages_for(website):
    return [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": "必须使用中文输出" + user_prompt_prefix + website}
    ]

# %%
# 试试看，然后再试几个网站

messages_for(ed)
# Out:
# [{'role': 'system',
#   'content': '\n中文回答,You are a snarky assistant that analyzes the contents of a website,\nand provides a short, snarky, humorous summary, ignoring text that might be navigation related.\nRespond in markdown. Do not wrap the markdown in a code block - respond just with the markdown.\n'},
#  {'role': 'user',
# ...

# %% [markdown]
# ## 是时候把它们整合起来了——OpenAI 的 API 非常简单！

# %%
# 现在：调用 OpenAI API。你会对此非常熟悉！

def summarize(url):
    # 抓取/构造网站内容，作为后续提示词的输入
    website = fetch_website_contents(url)
    # 调用 chat.completions.create：向大模型发一次对话请求并拿回复（同步、等全部生成完）
    response = openai.chat.completions.create(
        model = "qwen3:8b",
        # 组装 messages 列表：Chat Completions API 要求的对话格式（system / user / assistant）
        messages = messages_for(website)
    )
    return response.choices[0].message.content

# %%
summarize("https://edwarddonner.com")
# Out:
# '# Edward Donner的网站总结\n\n这位AI课程界的摇滚明星（曾是程序员，现转型教育博主）用他的Udemy课程成功完成了从“写代码”到“教育网红”的华丽转身。他的个人简介堪称自恋教科书：电子音乐制作（非常业余）+在Hacker News上点头如捣蒜+用300万学生证明自己“不务正业”的能力。  \n\n**课程时间线**（2025-2026）：  \n- 从“Vibe Coder”到“Agentic Engineer”的资源大礼包  \n- 用n8n打造AI Builder的语音代理工具包  \n- 真·MLOps工程师的上线指南（附带生产环境部署秘籍）  \n- 课程推荐顺序：请按我的指示做，否则你可能学不会  \n\n**隐藏彩蛋**：他的LinkedIn、Twitter和Facebook可能藏着更多关于“如何用AI赚快钱”的玄学。'

# %%
# 用 markdown 在输出中美观地显示结果的函数

def display_summary(url):
    # 拿到模型生成的摘要文本
    summary = summarize(url)
    # 用 Markdown 在笔记本中渲染格式化文本（display_id 方便后续原地刷新）
    display(Markdown(summary))

# %%
display_summary("https://edwarddonner.com")
# Out:
# # Edward Donner的个人网站总结
# **核心内容**：一个AI狂热者在分享他的“业余”电子音乐、UDemy课程（90万学员狂喜）以及如何用AI把代码写成“外交与诡计的战争”。
# **新闻速递**：最新资源更新包括“AI Coder: Vibe Coder到Agentic Engineer”的课程包（2026年发布），以及他那个叫“Outsmart”的LLM对战游戏（可能比《文明》更无聊）。
# **隐藏彩蛋**：他的Digital Avatar可能比他本人更会聊天——毕竟人类朋友已经受不了他“随机讲AI三小时”的能力了。

# %% [markdown]
# # 让我们试试更多网站
#
# 注意：这只适用于可以用这种简单方式抓取的网站。
#
# 用 Javascript 渲染的网站（如 React 应用）不会显示内容。请查看 community-contributions 文件夹中的 Selenium 实现来绕过此限制。你需要了解如何安装 Selenium（可以问 ChatGPT！）
#
# 另外，受 CloudFront（及类似服务）保护的网站可能会返回 403 错误——非常感谢 Andy J 指出这一点。
#
# 但许多网站都能正常工作！

# %%
display_summary("https://cnn.com")
# Out:
# **CNN首页总结**
# **Breaking News**：新闻栏目多到像超市货架，美国、世界、政治、商业……甚至还有“以色列-哈马斯战争”专区，仿佛人类文明只分为“战争”和“吃瓜”两种选择。
# **广告反馈**：用户被要求评估广告是否相关、是否卡顿、是否音量超标，仿佛在参加一场“人类对广告的生存挑战赛”。
# **隐藏彩蛋**：感谢用户参与反馈的段落，堪称“你的意见对我们比氧气还重要”的真诚表演。
# **终极结论**：CNN的首页像一本精装版《人性观察录》，每一条栏目都是对人类好奇心的精准打击，而广告反馈表则是在提醒你——**你已经被监控了**。

# %%
display_summary("https://anthropic.com")
# Out:
# # Anthropic官网速览：AI界的"安全卫士"自我感动现场
# **核心梗概**：一个自称致力于"让AI安全可控"的公司，用神话生物命名模型（Mythos/Fable），用《宪法》《军团》《指数政策》给自己贴满道德标签，最后在新闻区放了个未完成的Sonnet 5宣传文案——毕竟谁让AI的"安全"总和"科幻小说"走在一起呢？
#
# **亮点彩蛋**：
# - 模型名称疑似《山海经》再编：Opus（opus=歌剧）、Sonnet（十四行诗）、Haiku（俳句），AI界的文艺复兴？
# - "AI will have a vast impact"——这句话在官网出现三次，仿佛在给投资人打鸡血。
# - 最新"公告"写着"our most agentic Sonnet yet, wi"，连个标点符号都不完整，是懒癌发作还是故意吊人胃口？
#
# **总结**：Anthropic的官网就像一场AI界的自我感动现场，用政策文件当营销素材，拿模型名字搞文艺复兴，最后连个完整句子都懒得写——毕竟在安全和流量之间，他们选择了后者。

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">商业应用</h2>
#             <span style="color:#181;">在本练习中，你第一次体验了调用前沿模型（处于 AI 前沿的领先模型）的云端 API。在本课程的许多阶段我们都会使用像 OpenAI 这样的 API，此外还会构建我们自己的 LLM。
#
# 更具体地说，我们把它用在了摘要（Summarization）上——这是生成摘要的经典 Gen AI 用例。它可以应用于任何业务领域——总结新闻、总结财务表现、把简历总结进求职信——应用场景无穷无尽。想想你如何在业务中应用摘要，并尝试制作一个原型。</span>
#         </td>
#     </tr>
# </table>
#
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">继续之前——现在自己试试</h2>
#             <span style="color:#900;">使用下方单元格制作你自己的简单商业示例。目前先继续使用摘要用例。这里有一个想法：写一个程序，接收邮件内容，并建议一个合适的简短主题行。这正是可能被集成到商业邮件工具中的功能类型。</span>
#         </td>
#     </tr>
# </table>

# %%
# 步骤 1：创建你的提示词

system_prompt = "something here"
# 用户提示词（user prompt）：本次要模型完成的具体任务与输入内容
user_prompt = """
    Lots of text
    Can be pasted here
"""

# 步骤 2：构建 messages 列表

messages = [] # fill this in

# 步骤 3：调用 OpenAI
# response =

# 步骤 4：打印结果
# print(

# %% [markdown]
# ## 给喜欢网页抓取的人的额外练习
#
# 你可能注意到，如果尝试 `display_summary("https://openai.com")`——它没法用！因为 OpenAI 有一个使用 Javascript 的精美网站。有许多绕过方法，你们中一些人可能已经熟悉。例如，Selenium 是一个非常流行的框架，它在后台运行浏览器、渲染页面，并允许你查询它。如果你有 Selenium、Playwright 或类似浏览器自动化框架的经验，可以随意用这些工具在 `scraper.py`（或单独模块）中实现抓取函数的替代版本。在 community-contributions 文件夹中，你会找到其他学员贡献的示例，包括一个 Selenium 实现（谢谢！）

# %% [markdown]
# # 分享你的代码
#
# 我很希望你之后分享代码，这样我就能分享给其他人！你会注意到一些学员已经做了改动（包括 Selenium 实现），可以在 community-contributions 文件夹中找到。如果想把你的改动加入该文件夹，请提交包含新版本的 Pull Request，我会合并你的更改。
#
# 如果你不是 git 专家（我也不是！），我在 guides 文件夹的指南 3 中给出了完整说明，并粘贴在这里：
#
# 以下是创建 PR 的整体步骤和关键说明：
# https://edwarddonner.com/pr
#
# 提交前请检查：
# 1. 你的 PR 只包含 community-contributions 中的更改（除非我们另有讨论）
# 2. 所有 notebook 输出已清空
# 3. 总计少于 2,000 行代码，文件也不要太多
# 4. 不要包含不必要的测试文件、过于冗长的 README 或 .env.example，也不要 emoji 或其他 LLM 产物！
#
# 非常感谢！
#
# 详细步骤在此：
#
# https://chatgpt.com/share/6873c22b-2a1c-8012-bc9a-debdcf7c835b
