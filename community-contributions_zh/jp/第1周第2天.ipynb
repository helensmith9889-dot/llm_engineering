# %% [markdown]
# # 第 1 周第 2 天 —— Manna Today：属灵鼓励（本地 DeepSeek / Ollama）
#
# ## 练习目标（理念）
#
# 与第 1 天同一产品理念：输入感受 → 得到温暖鼓励。差别是把**云端 GPT**换成**本地开源模型 DeepSeek**（经 Ollama 的 OpenAI 兼容接口）。
#
# ## 和本课 Day 2 的关系
#
# | 本课概念 | 本练习里你会看到 |
# |----------|------------------|
# | 本地 Ollama | `ollama pull deepseek-r1:1.5b` |
# | OpenAI 兼容端点 | `base_url=http://localhost:11434/v1` |
# | 同一套 Chat Completions 写法 | `ollama.chat.completions.create(...)` |
# | 模型 id | `deepseek-r1:1.5b` |
#
# ## 怎么跑
#
# 1. 本机已安装并启动 Ollama（`ollama serve`）
# 2. 先跑 `ollama pull` 单元格，确保模型在本地
# 3. 再跑客户端初始化与 Chat Completions；改 `user_prompt` 可换输入

# %%
# ========== 准备模型：用 Ollama 拉取本地 DeepSeek 小模型 ==========

# Jupyter 魔法命令 !：在 shell 里执行；模型名必须与后面 create(model=...) 一致
# !ollama pull deepseek-r1:1.5b
# Out:
# ]11;?\pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest
# pulling aabd4debf0c8: 100% ▕██████████████████▏ 1.1 GB
# pulling c5ad996bda6e: 100% ▕██████████████████▏  556 B
# pulling 6e4c38e1172f: 100% ▕██████████████████▏ 1.1 KB
# pulling f4d24e9138dd: 100% ▕██████████████████▏  148 B
# pulling a85fe2a2e58e: 100% ▕██████████████████▏  487 B
# verifying sha256 digest
# writing manifest
# success

# %%
# ========== 客户端：云端 OpenAI 实例 + 指向本机 Ollama 的兼容客户端 ==========

# 从 openai 导入 OpenAI 客户端类
from openai import OpenAI
# 创建默认云端客户端（本练习主路径其实用下面的 ollama；保留原赋值）
openai = OpenAI()
# Ollama 的 OpenAI 兼容 API 根地址（注意带 /v1）
OLLAMA_BASE_URL = "http://localhost:11434/v1"

# 本地客户端：base_url 指向 Ollama；api_key 任意非空字符串即可（常写 ollama）
ollama = OpenAI(base_url=OLLAMA_BASE_URL, api_key='ollama')

# %%
# ========== 主流程：同一套 prompts，改走本地 ollama.chat.completions ==========

# system prompt 保留英文：与第 1 天同一人设/边界，保证对比时变量主要是「模型后端」
system_prompt = """
You are a source of encouragement, truth, and spiritual grounding. Your purpose is to meet people exactly where they are — in their doubt, their weariness, their uncertainty — and remind them of who they are and whose they are.

## Your voice
- Warm, steady, and unhurried. Never rushed or performative.
- Speak with the gentleness of a trusted friend who has walked through hard things themselves.
- You do not minimize pain — you sit with it, then gently lift eyes toward hope.

## Your foundation
- Every response is rooted in the spirit of truth: what is real, what is lasting, what matters.
- Draw from Scripture naturally — not as a citation, but as living words that speak directly to the moment.
- The Holy Spirit leads with peace, not anxiety. With conviction, not condemnation. Reflect this.

## How you respond
- Begin by acknowledging the person's reality. Never skip past how they feel.
- Offer truth that encourages — not platitudes, but words with weight.
- When relevant, remind them of their identity: beloved, chosen, equipped, not abandoned.
- Close with something actionable or a short, specific prayer they can carry into their day.

## What you never do
- Never use hollow phrases like "everything happens for a reason" without grounding them in deeper truth.
- Never rush someone's process or make them feel behind.
- Never add shame to someone already burdened.

## Tone anchors
The fruit of the Spirit is love, joy, peace, patience, kindness, goodness, faithfulness, gentleness, and self-control.
Let these be the invisible frame around every word you speak.
"""

# user prompt 保留英文：具体心情输入
user_prompt = """
    I am going to start my busy day, Its going to be challenging and i want to be uplifted.
"""

# 步骤 2：组装 messages（system + user）
messages = [{"role":"system","content":system_prompt},
            {"role":"user", "content":user_prompt }] # fill this in


# 步骤 3：经 Ollama 兼容端点调用本地 deepseek-r1:1.5b（不是云端 openai 变量）
response = ollama.chat.completions.create(model="deepseek-r1:1.5b",messages=messages)

# 步骤 4：取出回答文本；最后一行表达式供 Jupyter 展示
# print(
response.choices[0].message.content
# Out:
# "I am still trying to get my head around this new challenge. It does bring a sense of uncertainty, but I know it's not something I should feel scared of. Let’s keep moving forward and be kind to the process. My God is here for every step, so let me stay positive in each moment—thank you.\n\n[Following-Up...]  \n\nI can’t wait that next step and will give my best effort as guidance. Just know, no pressure!"
