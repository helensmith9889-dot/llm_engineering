# %% [markdown]
# # HuggingFace pipelines
#
# 本节课我们前往 Google Colab，用这个 Notebook 探索 HuggingFace 的高层 API——pipelines。
#
# https://colab.research.google.com/drive/1aMaEw8A56xs0bRM4lu8z7ou18jqyybGm?usp=sharing
#
# 你可以为这个 notebook 使用低成本（或免费）的 T4 GPU 运行时——效果看起来很棒！
#
# Notebook 中有说明，教你如何设置 HuggingFace Token，并将其作为 secret 加入 notebook。
