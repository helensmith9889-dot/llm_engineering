# %% [markdown]
# # 第 1 天练习 - 简单 API 解释生成器
#
# 使用 OpenAI 的 API 以及系统和用户提示生成清晰、结构化解释的快速示例。
#
# 作者：玛丽亚姆·贾纳蒂·伊德里西

# %%
# 下方为可执行代码（逻辑与字符串保持原文，便于运行）
import os
from dotenv import load_dotenv
from openai import OpenAI

load_dotenv(override=True)
openai = OpenAI()

# %%
# 第 1 步：创建提示
system_prompt = "You are a helpful assistant that writes clear, structured, and concise answers."
user_prompt = """
Explain what an API is in simple terms.
Give an example related to everyday life.
Keep it short.
"""

# 第 2 步：创建消息列表
messages = [
    {"role": "system", "content": system_prompt},
    {"role": "user", "content": user_prompt}
]

# 第三步：调用OpenAI
# 温度控制随机性：
# 0.0-0.3 -> 非常可预测，一致（有利于编码）
# 0.5-0.8 -> 平衡（最佳默认值）
# 0.9+ -> 有创意但不太可靠

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages,
    temperature=0.7
)

# 第四步：打印结果
print(response.choices[0].message.content)
