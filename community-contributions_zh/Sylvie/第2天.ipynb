# %% [markdown]
# # 欢迎来到第二天实验室！

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="宽度：150px；高度：150px；垂直对齐：中间；">
#             <img src="../assets/resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">在我们开始之前 --</h2>
#             <span style="color:#f71;">我想花点时间向您介绍本课程的有用资源页面。这包括所有幻灯片的链接。<br/>
#             <a href="https://edwarddonner.com/2024/11/13/llm-engineering-resources/">https://edwarddonner.com/2024/11/13/llm-engineering-resources/</a><br/>
#             请保留此书签，随着时间的推移，我将继续添加更多有用的链接。
#             </span>
#         </td>
#     </tr>
# </表>

# %% [markdown]
# ## 首先 - 我们来谈谈聊天完成 API
#
# 1. 最简单的LLM申请方式
# 2.它被称为“聊天完成”，因为它说：“这是一个对话，请预测接下来会发生什么”
# 3. Chat Completions API 是 OpenAI 发明的，但它非常流行，每个人都在使用它！
#
# ### 我们将首先再次调用 OpenAI - 但不用担心非 OpenAI 的人，你的时代即将到来！

# %%
# 小白提示：下面代码逻辑未改，仅补充中文注释便于阅读
import os
from dotenv import load_dotenv

load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

if not api_key:
    print("No API key was found - please head over to the troubleshooting notebook in this folder to identify & fix!")
elif not api_key.startswith("sk-proj-"):
    print("An API key was found, but it doesn't start sk-proj-; please check you're using the right key - see troubleshooting notebook")
else:
    print("API key found and looks good so far!")

# %% [markdown]
# ## 你知道什么是端点吗？
#
# 如果没有，请查看指南文件夹中的技术基础指南
#
# 而且，这是您可能感兴趣的端点......

# %%
# 小白提示：下面代码逻辑未改，仅补充中文注释便于阅读
import requests

headers = {"Authorization": f"Bearer {api_key}", "Content-Type": "application/json"}

payload = {
    "model": "gpt-5-nano",
    "messages": [
        {"role": "user", "content": "Tell me a fun fact"}]
}

payload
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 import requests
# ----> 3 headers = {"Authorization": f"Bearer {api_key}", "Content-Type": "application/json"}
#       5 payload = {
#       6     "model": "gpt-5-nano",
#       7     "messages": [
#       8         {"role": "user", "content": "Tell me a fun fact"}]
#       9 }
#      11 payload
#
# NameError: name 'api_key' is not defined

# %%
# 小白提示：下面代码逻辑未改，仅补充中文注释便于阅读
response = requests.post(
    "https://api.openai.com/v1/chat/completions",
    headers=headers,
    json=payload
)

response.json()

# %%
# 小白提示：下面代码逻辑未改，仅补充中文注释便于阅读
response.json()["choices"][0]["message"]["content"]

# %% [markdown]
# # openai 包是什么？
#
# 它被称为 Python 客户端库。
#
# 它只不过是对 http 端点进行精确调用的包装器。
#
# 它只是允许你使用漂亮的 Python 代码，而不是乱搞乱七八糟的 json 对象。
#
# 但仅此而已。它是开源且轻量级的。有些人认为它包含 OpenAI 模型代码 - 事实并非如此！

# %%
# 小白提示：下面代码逻辑未改，仅补充中文注释便于阅读
# 创建 OpenAI 客户端

from openai import OpenAI
openai = OpenAI()

response = openai.chat.completions.create(model="gpt-5-nano", messages=[{"role": "user", "content": "Tell me a fun fact"}])

response.choices[0].message.content
# Out:
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# Cell In[2], line 4
#       1 # Create OpenAI client
#       3 from openai import OpenAI
# ----> 4 openai = OpenAI()
#       6 response = openai.chat.completions.create(model="gpt-5-nano", messages=[{"role": "user", "content": "Tell me a fun fact"}])
#       8 response.choices[0].message.content
#
# File d:\晓慧的阴间文件夹\人工智能\大模型学习\project\llm_engineering\.venv\Lib\site-packages\openai\_client.py:137, in OpenAI.__init__(self, api_key, organization, project, webhook_secret, base_url, websocket_base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation)
#     135     api_key = os.environ.get("OPENAI_API_KEY")
#     136 if api_key is None:
# --> 137     raise OpenAIError(
# ...

# %% [markdown]
# ## 然后这件伟大的事情发生了：
#
# OpenAI 的聊天完成 API 非常受欢迎，以至于其他模型提供商创建了相同的端点。
#
# 它们被称为“OpenAI 兼容端点”。
#
# 例如，谷歌在这里做了一个：https://generativelanguage.googleapis.com/v1beta/openai/
#
# OpenAI 决定友善一点：他们说，嘿，你可以使用我们为 GPT 制作的相同客户端库。我们将允许您指定不同的端点 URL 和不同的密钥，以使用其他提供商。
#
# 所以你可以使用：
#
# ```python
# gemini = OpenAI(base_url="https://generativelanguage.googleapis.com/v1beta/openai/", api_key="AIz....")
# gemini.chat.completions.create(...)
# ```
#
# 需要明确的是，尽管 OpenAI 存在于代码中，但我们仅使用这个轻量级 python 客户端库来调用端点 - 这里不涉及 OpenAI 模型。
#
# 如果您感到困惑，请查看 Guides 文件夹中的 Guide 9！
#
# 现在让我们尝试一下！
#
# ## 这是可选的 - 但如果您想尝试 Google Gemini，请访问：
#
# https://aistudio.google.com/
#
# 并设置您的 API 密钥
#
# https://aistudio.google.com/api-keys
#
# 然后将您的密钥添加到“.env”文件中，并确保在更改后保存 .env 文件：
#
# `GOOGLE_API_KEY=AIz...`

# %%
# 小白提示：下面代码逻辑未改，仅补充中文注释便于阅读
GEMINI_BASE_URL = "https://generativelanguage.googleapis.com/v1beta/openai/"

load_dotenv(override=True)

google_api_key = os.getenv("GOOGLE_API_KEY")

if not google_api_key:
    print("No API key was found - please be sure to add your key to the .env file, and save the file! Or you can skip the next 2 cells if you don't want to use Gemini")
elif not google_api_key.startswith("AIz"):
    print("An API key was found, but it doesn't start AIz")
else:
    print("API key found and looks good so far!")

# %%
# 小白提示：下面代码逻辑未改，仅补充中文注释便于阅读
gemini = OpenAI(base_url=GEMINI_BASE_URL, api_key=google_api_key)

response = gemini.chat.completions.create(model="gemini-2.5-flash-lite", messages=[{"role": "user", "content": "Tell me a fun fact"}])

response.choices[0].message.content

# %% [markdown]
# ## Ollama 还提供了一个兼容 OpenAI 的端点
#
# ...它在您的本地计算机上！
#
# 如果下一个单元格未打印“Ollama is running”，请打开终端并运行 `ollamaserve`

# %%
# 小白提示：下面代码逻辑未改，仅补充中文注释便于阅读
requests.get("http://localhost:11434").content
# Out:
# b'Ollama is running'

# %% [markdown]
# ### 从元下载 llama3.2
#
# 如果您的计算机较小，请将其更改为 llama3.2:1b。
#
# 不要使用 llama3.3 或 llama4！它们对你的电脑来说太大了..

# %%
# !ollama pull llama3.2

# %%
# 小白提示：下面代码逻辑未改，仅补充中文注释便于阅读
OLLAMA_BASE_URL = "http://localhost:11434/v1"

ollama = OpenAI(base_url=OLLAMA_BASE_URL, api_key='ollama')

# %%
# 小白提示：下面代码逻辑未改，仅补充中文注释便于阅读
# 获取一个有趣的事实

response = ollama.chat.completions.create(model="llama3.2", messages=[{"role": "user", "content": "Tell me a fun fact"}])

response.choices[0].message.content
# Out:
# 'Here\'s one:\n\nDid you know that there is a species of jellyfish that is immortal? The Turritopsis dohrnii, also known as the "immortal jellyfish," can transform its body into a younger state through a process called transdifferentiation. This means it can essentially revert back to its polyp stage, which is the juvenile form of a jellyfish, and then grow back into an adult again. This process can be repeated indefinitely, making the Turritopsis dohrnii theoretically immortal!'

# %%
# 小白提示：下面代码逻辑未改，仅补充中文注释便于阅读
# 现在让我们尝试 deepseek-r1:1.5b - 这是从阿里云“提炼”成 Qwen 的 DeepSeek

# !ollama pull deepseek-r1:1.5b

# %%
# 小白提示：下面代码逻辑未改，仅补充中文注释便于阅读
response = ollama.chat.completions.create(model="deepseek-r1:1.5b", messages=[{"role": "user", "content": "Tell me a fun fact"}])

response.choices[0].message.content

# %% [markdown]
# # 家庭作业练习作业
#
# 升级第 1 天项目以总结网页，以使用通过 Ollama 而不是 OpenAI 在本地运行的开源模型
#
# 如果您不想使用付费 API，您将能够在所有后续项目中使用此技术。
#
# **好处：**
# 1.无API收费——开源
# 2. 数据不会离开你的盒子
#
# **缺点：**
# 1. 功耗明显低于 Frontier 模型
#
# ## Ollama 安装回顾
#
# 只需访问 [ollama.com](https://ollama.com) 并安装即可！
#
# 完成后，ollama 服务器应该已经在本地运行。
# 如果您访问：
# [http://localhost:11434/](http://localhost:11434/)
#
# 您应该看到消息“Ollama 正在运行”。
#
# 如果没有，请打开新的终端 (Mac) 或 Powershell (Windows) 并输入 `ollamaserve`
# 在另一个终端 (Mac) 或 Powershell (Windows) 中，输入 `ollama pull llama3.2`
# 然后再次尝试 [http://localhost:11434/](http://localhost:11434/)。
#
# 如果 Ollama 在您的计算机上运行缓慢，请尝试使用“llama3.2:1b”作为替代方案。从终端或 Powershell 运行 `ollama pull llama3.2:1b`，并将代码从 `MODEL = "llama3.2"` 更改为 `MODEL = "llama3.2:1b"`

# %%
# 小白提示：下面代码逻辑未改，仅补充中文注释便于阅读
OLLAMA_BASE_URL = "http://localhost:11434/v1"

ollama = OpenAI(base_url=OLLAMA_BASE_URL, api_key='llama3.2')
system_prompt = "You are a professional business email assistant. Your task is to generate a concise, accurate and professional subject line based on the email body provided by the user. Only output the subject line, do not include any additional explanations or punctuation marks apart from this."
email_body = """
Hi team,

Could you please review the attached Q3 sales report and share your feedback by Friday? 
We need to finalize the numbers before the board meeting next Monday.

Thanks,
Alex
"""
user_prompt = f"Please generate an appropriate subject line for the following email content:\n\n{email_body}"

messages = [
    {"role": "system", "content":system_prompt },
    {"role": "user", "content": user_prompt}
]

response = ollama.chat.completions.create(model="llama3.2", messages=messages)
response.choices[0].message.content
# Out:
# 'Q3 Sales Report Review Deadline This Friday'
