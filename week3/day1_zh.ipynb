# %% [markdown]
# # 认识 Colab
#
# 了解 Google Colab，并（如果你还没有的话）设置一个 Google 账号：[点这里](https://colab.research.google.com/)
#
# 完成本课程所有项目，使用免费套餐或极少花费即可。我自己注册了 Colab Pro+，体验很棒——但不是必须的。
#
# 想看看 Colab 能做什么，请点击下面的链接！
#
# https://colab.research.google.com/drive/1DjcrYDZldAXKJ08x1uYIVCtItoLPk1Wr?usp=sharing
