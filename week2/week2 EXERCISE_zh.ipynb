# %% [markdown]
# # 额外周末练习 — 第 2 周
#
# 现在运用你在第 2 周学到的一切，为第 1 周练习中构建的技术问答器做一个完整原型。
#
# 应包括 Gradio UI、流式输出、用系统提示词增加专业性，以及在模型之间切换的能力。如果你能演示工具的使用，还有加分！
#
# 如果你够大胆，可以试试加入音频输入，这样你就能对着它说话，并让它用音频回复。ChatGPT 或 Claude 可以帮你，有问题也可以给我发邮件。
#
# 我很快会在这里发布完整解决方案——除非有人抢先……
#
# 这有无数商业应用：从语言导师，到公司入职方案，再到课程的伴学 AI（就像这门课！）。我迫不及待想看到你们的成果。
