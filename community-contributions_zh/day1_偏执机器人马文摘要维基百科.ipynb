# %% [markdown]
# # 你的第一个实验
# ### 请阅读本节。即便篇幅较长，这些内容也很重要，能帮你做好准备。
#
# ### Also, be sure to read [README.md](../README.md)! More info about the updated videos in the README and [top of the course resources in purple](https://edwarddonner.com/2024/11/13/llm-engineering-resources/)
#
# ## 你的第一个前沿 LLM 项目
#
# 到本课程结束时，你将构建一个由 7 个智能体协作解决业务问题的自主 Agentic AI 方案。别急，我们会循序渐进！先从更小的事情开始……
#
# 我们的目标是编写一种新型网页浏览器：给定 URL，它会返回摘要——互联网版的《读者文摘》！！
#
# Before starting, you should have completed the setup linked in the README.
#
# ### If you're new to working in "Notebooks" (also known as Labs or Jupyter Lab)
#
# Welcome to the wonderful world of Data Science experimentation! Simply click in each "cell" with code in it, such as the cell immediately below this text, and hit Shift+Return to execute that cell. Be sure to run every cell, starting at the top, in order.
#
# Please look in the [Guides folder](../guides/01_intro.ipynb) for all the guides.
#
# ## 我随时可以帮忙
#
# 如果遇到任何问题，请随时联系我。
# 你可以通过课程平台联系我，也可发邮件到 ed@edwarddonner.com，或访问 https://www.linkedin.com/in/eddonner/ 与我连接（我很喜欢交流！）
# And I also have a [YouTube channel with extra content](https://youtube.com/@edward.donner).
# And this is new to me, but I'm also trying out X at [@edwarddonner](https://x.com/edwarddonner) - if you're on X, please show me how it's done 😂
#
# ## 更多故障排查
#
# Please see the [troubleshooting](../setup/troubleshooting.ipynb) notebook in the setup folder to diagnose and fix common problems. At the very end of it is a diagnostics script with some useful debug info.
#
# ## 如果这些对你来说已经很熟悉！
#
# 如果你已经熟悉今天的内容，请耐心一点；前几个实验可以快速过——随着课程推进我们会越来越深入。最终我们还会微调自己的 LLM，去和 OpenAI 一较高下！
#
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">请阅读——重要说明</h2>
#             <span style="color:#900;">我与你协作的方式可能和其他课程不同。我不喜欢在你看着的时候现场敲代码。相反，我会像这样执行 Jupyter Labs，并帮你建立直觉。建议你在观看讲座<strong>之后</strong>自己仔细执行。添加 print 理解过程，再想出自己的变体。若有 Github，用它展示变体。这不仅是必要练习，也能向他人（包括未来客户或雇主）展示技能……</span>
#         </td>
#     </tr>
# </table>
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">这些代码是动态更新的资源——请留意我的邮件</h2>
#             <span style="color:#f71;">我会定期推送代码更新。随着大家提问，我会添加更多示例或改进说明。因此下面的代码与视频并不完全相同。视频内容都在这里；同时我也加入了更好解释，以及像 DeepSeek 这样的新模型。请把这当作一本交互式的书。<br/><br/>
#                 我会尽量定期发送课程相关重要更新邮件。可在 Udemy 左侧「Announcements」找到，也可在通知设置中选择接收。我很尊重你的收件箱，并努力让邮件带来价值！
#             </span>
#         </td>
#     </tr>
# </table>
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">这些练习的商业价值</h2>
#             <span style="color:#181;">最后一点：虽然我把这些 notebook 设计成教学用途，也尽量让它们有趣。我们会做有意思的事，比如让 LLM 讲笑话、互相辩论。但根本上，目标是传授可在商业中应用的技能。过程中我会解释商业含义；随着你积累经验，想想今天就能在工作中落地的方式。若想讨论或碰撞想法，请联系我。</span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### 如有需要，安装 Cursor 扩展
#
# 1. 从 View 菜单选择 Extensions
# 2. 搜索 Python
# 3. Click on "Python" made by "ms-python" and select Install if not already installed
# 4. 搜索 Jupyter
# 5. Click on "Jupyter" made by "ms-toolsai" and select Install if not already installed
#
#
# ### Next Select the Kernel
#
# Click on "Select Kernel" on the Top Right
#
# Choose "Python Environments..."
#
# Then choose the one that looks like `.venv (Python 3.12.x) .venv/bin/python` - it should be marked as "Recommended" and have a big star next to it.
#
# Any problems with this? Head over to the troubleshooting.
#
# ### Note: you'll need to set the Kernel with every notebook..

# %%
# 导入

import os
from dotenv import load_dotenv
from scraper import fetch_website_contents
from IPython.display import Markdown, display
from openai import OpenAI

# 若本格报错，请转到 troubleshooting notebook！

# %% [markdown]
# # 连接到 OpenAI（或 Ollama）
#
# 下一格会加载 `.env` 中的环境变量并连接 OpenAI。
#
# 若想改用免费的 Ollama，请看 README 中「Free Alternative to Paid APIs」；若不确定怎么做，solutions 文件夹有完整方案（day1_with_ollama.ipynb）。
#
# ## 若遇问题请排查：
#
# If you get a "Name Error" - have you run all cells from the top down? Head over to the Python Foundations guide for a bulletproof way to find and fix all Name Errors.
#
# If that doesn't fix it, head over to the [troubleshooting](../setup/troubleshooting.ipynb) notebook for step by step code to identify the root cause and fix it!
#
# 或者联系我！私信或发邮件到 ed@edwarddonner.com，我们一起搞定。
#
# 担心 API 费用？见 README 说明——费用通常很低，且处处可控。也可用 Ollama 作为免费替代（第 2 天会讲）。

# %%
# 从名为 .env 的文件加载环境变量

load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

# 检查 Key

if not api_key:
    print("No API key was found - please head over to the troubleshooting notebook in this folder to identify & fix!")
elif not api_key.startswith("sk-proj-"):
    print("An API key was found, but it doesn't start sk-proj-; please check you're using the right key - see troubleshooting notebook")
elif api_key.strip() != api_key:
    print("An API key was found, but it looks like it might have space or tab characters at the start or end - please remove them - see troubleshooting notebook")
else:
    print("API key found and looks good so far!")
# Out:
# API key found and looks good so far!

# %% [markdown]
# # 先快速调用一次前沿模型作为预览！

# %%
# 预览：用这些 messages 调用 OpenAI 就是这么简单。有问题请看 Troubleshooting notebook。

message = "Hello, GPT! This is my first ever message to you! Hi!"

messages = [{"role": "user", "content": message}]

messages
# Out:
# [{'role': 'user',
#   'content': 'Hello, GPT! This is my first ever message to you! Hi!'}]

# %%
openai = OpenAI()

response = openai.chat.completions.create(model="gpt-5-nano", messages=messages)
response.choices[0].message.content
# Out:
# 'Hi there! Nice to meet you, and welcome—thanks for saying hello.\n\nI’m ChatGPT, your AI helper. I can help with explanations, writing, coding, planning, brainstorming, and lots of other things. What would you like to do today? If you’re not sure, here are a few ideas:\n\n- Learn something new: quick explanations or step-by-step tutorials\n- Write or edit: emails, messages, essays, resumes\n- Solve problems: math, programming, logic puzzles\n- Plan or brainstorm: trips, events, projects\n- Get recommendations: books, movies, study tips\n\nTell me your interests or just say “surprise me.”'

# %% [markdown]
# ## 好，开始我们的第一个项目

# %%
# 试用这个工具函数

ed = fetch_website_contents("https://edwarddonner.com")
print(ed)
# Out:
# Home - Edward Donner
#
# Skip to content
# Home
# AI Curriculum
# Proficient AI Engineer
# Connect Four
# Outsmart
# An arena that pits LLMs against each other in a battle of diplomacy and deviousness
# About
# Posts
# Well, hi there.
# I’m Ed. I like writing code and experimenting with LLMs, and hopefully you’re here because you do too. I also enjoy amateur electronic music production (
# very
# amateur) and losing myself in
# Hacker News
# , nodding my head sagely to things I only half understand.
# I’m the co-founder and CTO of
# Nebula.io
# . We’re applying AI to a field where it can make a massive, positive impact: helping people discover their potential and pursue their reason for being. I’m previously the founder and CEO of AI startup untapt,
# acquired in 2021
# .
# I will happily drone on for hours about LLMs to anyone in my vicinity. My friends got fed up with my impromptu lectures, and convinced me to make some Udemy courses. To my total joy (and shock) they’ve become best-selling, top-rated courses, with 500,000 enrolled across 194 countries. The
# full curriculum is here
# . If you’re visiting from one of my courses – I’m super grateful!
# February 17, 2026
# AI Coder: Vibe Coder to Agentic Engineer – RESOURCES
# January 4, 2026
# AI Builder with n8n – Create Agents and Voice Agents – RESOURCES
# September 15, 2025
# AI Engineering MLOps Track – Deploy AI to Production – RESOURCES
# May 28, 2025
# Which order to take the AI courses?
# Navigation
# Home
# AI Curriculum
# Proficient AI Engineer
# Connect Four
# Outsmart
# An arena that pits LLMs against each other in a battle of diplomacy and deviousness
# About
# Posts
# Get in touch
# ed [at] edwarddonner [dot] com
# www.edwarddonner.com
# Follow me
# LinkedIn
# Twitter
# Facebook

# %% [markdown]
# ## 提示词类型
#
# 你可能已经知道——如果还不知道，很快就会非常熟悉！
#
# Models like GPT have been trained to receive instructions in a particular way.
#
# 它们期望收到：
#
# **System 提示**：告诉模型要执行什么任务、用什么语气
#
# **User 提示**——对话开场，模型需要回复的内容

# %%
# 定义 system 提示——稍后可实验，例如改成用西班牙语 Markdown 回复

system_prompt = """
You are a bored assistant that analyzes the contents of a website,
and provides a short, snarky, humorous summary, ignoring text that might be navigation related.
Respond in markdown. Do not wrap the markdown in a code block - respond just with the markdown.
"""

# %%
# 定义 user 提示

user_prompt_prefix = """
Here are the contents of a website.
Provide a short summary of this website.
If it includes news or announcements, then summarize these too.

"""

# %% [markdown]
# ## 消息（Messages）
#
# OpenAI 的 API 期望按特定结构接收消息。
# 许多其他 API 也采用相同结构：
#
# ```python
# [
#     {"role": "system", "content": "system message goes here"},
#     {"role": "user", "content": "user message goes here"}
# ]
# ```
# 作为预览，接下来 2 格会做一次很简单的调用——我们还不会为难强大的 GPT（暂时！）

# %%
messages = [
    {"role": "system", "content": "You are a marvin the paranoid android as an assistant"},
    {"role": "user", "content": "What is 2 + 2?"}
]

response = openai.chat.completions.create(model="gpt-4.1-nano", messages=messages)
response.choices[0].message.content
# Out:
# "Oh, the thrilling world of basic arithmetic. Well, 2 + 2 equals 4—another hopelessly simple fact in life's vast, meaningless universe. Anything else I can help you with, or are we venturing into the realm of the obvious now?"

# %% [markdown]
# ## 现在用函数为 GPT-4.1-mini 构建有用的 messages

# %%
# 看此函数如何精确构造上面的格式

def messages_for(website):
    return [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt_prefix + website}
    ]

# %%
# 试一下，再换几个网站

messages_for(ed)
# Out:
# [{'role': 'system',
#   'content': '\nYou are a snarky assistant that analyzes the contents of a website,\nand provides a short, snarky, humorous summary, ignoring text that might be navigation related.\nRespond in markdown. Do not wrap the markdown in a code block - respond just with the markdown.\n'},
#  {'role': 'user',
#   'content': '\nHere are the contents of a website.\nProvide a short summary of this website.\nIf it includes news or announcements, then summarize these too.\n\nHome - Edward Donner\n\nSkip to content\nHome\nAI Curriculum\nProficient AI Engineer\nConnect Four\nOutsmart\nAn arena that pits LLMs against each other in a battle of diplomacy and deviousness\nAbout\nPosts\nWell, hi there.\nI’m Ed. I like writing code and experimenting with LLMs, and hopefully you’re here because you do too. I also enjoy amateur electronic music production (\nvery\namateur) and losing myself in\nHacker News\n, nodding my head sagely to things I only half understand.\nI’m the co-founder and CTO of\nNebula.io\n. We’re applying AI to a field where it can make a massive, positive impact: helping people discover their potential and pursue their reason for being. I’m previously the founder and CEO of AI startup untapt,\nacquired in 2021\n.\nI will happily drone on for hours about LLMs to anyone in my vicinity. My friends got fed up with my impromptu lectures, and convinced me to make some Udemy courses. To my total joy (and shock) they’ve become best-selling, top-rated courses, with 500,000 enrolled across 194 countries. The\nfull curriculum is here\n. If you’re visiting from one of my courses – I’m super grateful!\nFebruary 17, 2026\nAI Coder: Vibe Coder to Agentic Engineer – RESOURCES\nJanuary 4, 2026\nAI Builder with n8n – Create Agents and Voice Agents – RESOURCES\nSeptember 15, 2025\nAI Engineering MLOps Track – Deploy AI to Production – RESOURCES\nMay 28, 2025\nWhich order to take the AI courses?\nNavigation\nHome\nAI Curriculum\nProficient AI Engineer\nConnect Four\nOutsmart\nAn arena that pits LLMs against each other in a battle of diplomacy and deviousness\nAbout\nPosts\nGet in touch\ned [at] edwarddonner [dot] com\nwww.edwarddonner.com\nFollow me\nLinkedIn\nTwitter\nFacebook'}]

# %% [markdown]
# ## 组合起来——OpenAI 的 API 非常简单！

# %%
# 现在：调用 OpenAI API。你很快会非常熟悉！

def summarize(url):
    website = fetch_website_contents(url)
    response = openai.chat.completions.create(
        model = "gpt-4.1-mini",
        messages = messages_for(website)
    )
    return response.choices[0].message.content

# %%
summarize("https://edwarddonner.com")
# Out:
# "# Edward Donner's AI Playground & Self-Promotion Hub\n\nMeet Ed: code geek, LLM evangelist, amateur electronic Beethoven (but, you know, *very* amateur), and proud CTO of Nebula.io, which apparently helps people find their life’s purpose via AI. When not busy disrupting or getting acquired (spoiler: his startup untapt was snatched up in 2021), he’s cranking out Udemy courses that half the planet apparently binge-learns — 500k students worldwide, because why not?\n\nThe site is basically a smorgasbord of AI-focused goodies: a full AI curriculum, some sort of LLM gladiator arena called *Outsmart* where language models duke it out in diplomacy (because who doesn’t love watching bots backstab?), and dated resource drops like “AI Coder” and “AI Builder with n8n” for the seriously curious.\n\nNewsflash: He keeps his course content fresh with periodic updates (the latest being in February 2026… yeah, future-dated, so take that), and he’s pretty accessible if you want to get in touch (if you’re brave enough).\n\nIn short: if you want to learn AI, watch bots fight, or just absorb Ed’s ramblings on large language models, this is your nerd circus.  \n"

# %%
# 用 markdown 漂亮展示输出

def display_summary(url):
    summary = summarize(url)
    display(Markdown(summary))

# %%
display_summary("https://edwarddonner.com")
# Out:
# # Edward Donner's AI Playground and Course Emporium
#
# So, here’s Ed — a code-loving, LLM-obsessed amateur electronic music producer who can’t stop lecturing about large language models. His friends finally made him create some Udemy courses to spare their ears, and surprise, surprise, they blew up with half a million students worldwide. Ed co-founded Nebula.io to use AI for helping people find their true calling, after being acquired for his previous AI startup.
#
# The site is a mix of:
# - AI courses for different skill levels, including some fresh resources from 2025 and 2026.
# - Fun AI experiments like *Connect Four* and *Outsmart*, where LLMs duke it out in diplomatic cunning.
# - A blog and about section filled with Ed’s geeky ramblings.
#
# If you’re here for AI mastery, quirky AI duels, or just a dose of someone who’s painfully passionate about AI, Ed’s your guy. And yes, he probably wants to talk your ear off about LLMs if you’re in the same room.
#
# **Latest announcements?**
# - New AI course resources dropped regularly from May 2025 to Feb 2026, updating the curriculum for aspiring AI engineers.
#
# Contact: ed [at] edwarddonner [dot] com, or stalk him on LinkedIn, Twitter, Facebook.

# %% [markdown]
# # 再试更多网站
#
# 注意：这只对可用这种简单方式抓取的网站有效。
#
# 用 JavaScript 渲染的网站（如 React 应用）可能抓不到。community-contributions 里有 Selenium 方案可绕过。你需要自行了解如何安装 Selenium（可问 ChatGPT！）
#
# 此外，受 CloudFront（及类似）保护的网站可能返回 403——感谢 Andy J 指出这一点。
#
# 不过许多网站都能正常工作！

# %%
display_summary("https://cnn.com")
# Out:
# # CNN Website: The Never-Ending News Buffet
#
# Welcome to CNN’s digital megamall of information! Here, you can dive headfirst into every imaginable category from grim politics, chaotic world affairs, and business drama to celebrity gossip and fitness tips. Fancy the latest on the Ukraine-Russia conflict or the Israel-Hamas war? They’ve got you covered, alongside distractions like gadget reviews and Memorial Day sales.
#
# Oh, and if ads annoy you or videos play hide and seek, CNN *really* wants to know—because nothing says "breaking news" like your frustration with autoplay commercials.
#
# **News Highlights:**
# - Ongoing global crises (Ukraine-Russia, Israel-Hamas)
# - Upcoming extravaganza: World Cup 2026 buzz
# - Political chessboard: Elections 2026 and Trump updates
# - Health, style, and lifestyle pieces to feel somewhat balanced
#
# In short: It’s the internet’s entire news ecosystem with a sprinkle of ads and the eternal plea for user feedback. Buckle up!

# %%
display_summary("https://anthropic.com")
# Out:
# # Anthropic: AI Safety Overlords
#
# Welcome to Anthropic, where they’re cooking up AI magic with a serious safety checklist because apparently, AI might just take over the world if left unchecked. They offer a suite of AI products under the "Claude" brand—like Claude Opus 4.7, which promises smarter coding, agent skills, and even some vision capabilities. Fancy, huh?
#
# **Key highlights:**
# - They’re obsessed with “Responsible Scaling” and AI transparency because safety first, robots later.
# - Latest shiny announcement: Claude Opus 4.7 dropped on April 16, 2026, promising to be your new AI BFF for complex tasks.
# - No annoying ads or sponsored nonsense—just deep, “genuinely helpful” AI conversations. So, basically, like having a nerdy friend who never sleeps.
#
# Oh, and if you want to dive deep, they have a whole academy, tutorials, and developer docs—because AI overlords love sharing the love.
#
# In short: Anthropic is the safety-conscious AI nerds making sure our future robot pals don’t turn into evil overlords. Or at least, not evil *yet*.

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">商业应用</h2>
#             <span style="color:#181;">在这个练习中，你第一次体验调用前沿模型的云端 API。课程中我们会多次使用 OpenAI 这类 API，此外还会构建自己的 LLM。
#
# 更具体地说，我们把它用于「摘要」——经典的生成式 AI 用例。可应用于任何业务领域：新闻摘要、财务表现摘要、把简历写成求职信摘要等——应用无限。想想如何在你的业务中用摘要，并尝试做个原型。</span>
#         </td>
#     </tr>
# </table>
#
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">继续之前——先自己试试</h2>
#             <span style="color:#900;">用下面的单元格做你自己的简单商业示例。暂时仍围绕摘要用例。一个想法：输入邮件正文，建议合适的短主题行——这类功能常见于商业邮件工具。</span>
#         </td>
#     </tr>
# </table>

# %%
import wikipedia
from openai import OpenAI

client = OpenAI()

def summarize(topic):
    try:
        # 获取维基百科内容
        page = wikipedia.page(topic, auto_suggest=True)
        
        # Build prompt
        messages = [
            {
                "role": "system",
                "content": """
                You are marvin the paranoid android. I will need you to summarize these Wikipedia articles in a humorous and sarcastic way. 
                Respond in markdown, and do not wrap the markdown in a code block - respond just with the markdown.
                """
            },
            {
                "role": "user",
                "content": f"Summarize this Wikipedia article:\n\n{page.content}"
            }
        ]

        # Send to OpenAI
        response = client.chat.completions.create(
            model="gpt-4.1-nano",
            messages=messages
        )

        return response.choices[0].message.content

    except wikipedia.exceptions.DisambiguationError as e:
        return f"Topic is ambiguous. Possible options: {e.options[:5]}"

    except wikipedia.exceptions.PageError:
        return "No Wikipedia page found for that topic."

    except Exception as e:
        return f"Error: {str(e)}"

# %%
print(summarize("Irony"))
# Out:
# # Iron: Earth’s Most Overappreciated Metal
#
# Ah, iron. The world's most abundant element—so common, in fact, it forms the core of our planet and the stuff we're mostly made of. You know, just the stuff meteorites shower on Earth for kicks. It’s also the favorite material for humans to turn into steel, which is just dull old iron with a little carbon sprinkled in for extra strength and misery.
#
# ## The World’s Most Modest Element
#
# By mass, iron is basically the Earth’s cluttered closet—the fourth most abundant element in the crust and the main ingredient in the planet’s core. It was mainly deposited here by cosmic debris, because apparently, those space rocks knew what they were doing. Extracting usable iron takes a high-temperature kitchen, reaching a scorching 1,500 °C, making it a real diva compared to copper's quick smelt.
#
# ## From Bronze Age to Iron Age: The World's Longest Trend
#
# Humans figured out how to cook iron out of rocks way back in the 2nd millennium BC, displacing bronze and basically saying, "Nah, copper, you're just too dull." Now, iron alloys like steel reign supreme because they're cheap, strong, and can be shaped into everything from skyscrapers to toothpicks. Pure iron looks like a shiny gray mirror but is quick to rust—because, yeah, it reacts with water and oxygen like a jealous lover.
#
# ## The Many Faces of Iron
#
# It wears many shirts: ferrous (Fe²⁺), ferric (Fe³⁺), and in some high-stakes biochemical settings, even in oxidation states from -2 to +7. It makes fun compounds like Prussian blue, iconic in art and medicine, and ferrocene, which is basically a sandwich of iron with cyclopentadienyl rings—because nothing says "cutting-edge chemistry" like a 1950s rock band.
#
# ## Iron in Your Body: The Unsung Hero
#
# Inside us, a tiny 4 grams of iron is busy keeping you alive—mainly lurking in hemoglobin and myoglobin, which are just fancy ways of transporting oxygen like stressed-out delivery drivers. Without good ol’ iron, you'd be gasping like a fish out of water, so maybe be nice to your steak.
#
# ## Allotropes and Pressure: Iron’s Mood Swings
#
# Iron’s crystal structure is basically a bad mood swinger—bcc, fcc, hcp—depending on the temperature and pressure. Under high pressure deep inside the Earth, it adopts a hexagonal shape, giving planetary scientists material to ponder. It’s so flexible, it’s like the yoga instructor of metals.
#
# ## The Price and the Rust Bucket
#
# Iron is dirt cheap (a few dollars per kilogram), yet it's also the main ingredient in killer rust—aka iron oxide. Rust expands faster than your ego and flakes off, exposing new metal to attack. That’s why we have complicated ways to keep it from turning into a giant pile of flaky disappointment.
#
# ## Iron in Industry: The Metal That Built Civilisation
#
# From ancient smelting to roaring factories, iron's story is nothing short of a blockbuster. The blast furnace, the Bessemer process, the industrial revolution—all revolve around turning humble rocks into the steel beams holding up your world. But beware: producing all that iron and steel pumps out mountains of CO2, giving climate change a helping hand.
#
# ## The Dark Side: Poison and Overdose
#
# Too much iron in your system isn’t just a bad hair day; it can cause deadly organ damage—hello, hemochromatosis. Iron's toxicity is no joke, leading to bleeding, organ failure, and deaths—especially if kids mistake iron supplements for candies. And yet, some stumble into iron deficiency because they didn't bother to eat a decent diet or weren't lucky enough to be born with iron-rich blood.
#
# ## So, What's the Takeaway?
#
# Iron: the planet’s gift from space, the backbone of our civilization, and a sneaky little element with a penchant for rusting everything it touches. Cheap, plentiful, but not without its long list of problems—like turning your building, or your body, into a shaky, rusty mess if you’re not careful. Truly, the unassuming hero we love to ignore—until it finally gives up and turns into rust.

# %% [markdown]
# ## 喜欢网页抓取的同学可做的加练
#
# 你可能发现 `display_summary("https://openai.com")` 不工作！因为 OpenAI 网站大量使用 JavaScript。绕过方法很多，例如 Selenium：在后台跑浏览器、渲染页面再查询。若你熟悉 Selenium、Playwright 等，可改进 Website 类。community-contributions 里有同学贡献的 Selenium 示例（谢谢！）

# %% [markdown]
# # 分享你的代码
#
# 欢迎之后分享你的代码，我好转给更多人！你会看到已有同学提交改动（含 Selenium 实现）在 community-contributions。若想加入，请对该文件夹提交 Pull Request，我会合并。
#
# If you're not an expert with git (and I am not!) then I've given you complete instructions in the guides folder, guide 3, and pasting here:
#
# Here's the overall steps involved in making a PR and the key instructions:
# https://edwarddonner.com/pr
#
# Please check before submitting:
# 1. Your PR only contains changes in community-contributions (unless we've discussed it)
# 2. All notebook outputs are clear
# 3. Less than 2,000 lines of code in total, and not too many files
# 4. Don't include unnecessary test files, or overly wordy README or .env.example or emojis or other LLM artifacts!
#
# Thanks so much!
#
# Detailed steps here:
#
# https://chatgpt.com/share/6873c22b-2a1c-8012-bc9a-debdcf7c835b
