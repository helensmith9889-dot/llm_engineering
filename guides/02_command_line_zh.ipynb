# %% [markdown]
# # 命令行

# %% [markdown]
# 欢迎来到这份帮助你建立命令行信心的指南。
#
# 学完本指南后，你应该能够自信地在命令行工作：创建目录、移动文件，以及更多！

# %% [markdown]
# ## 面向 Windows PC 用户
#
# 请参阅这份简报：
#
# https://chatgpt.com/share/68064acf-4d3c-8012-86a1-fb09a7c6f923

# %% [markdown]
# ## 面向 Mac 用户
#
# 请参阅这份简报：
#
# https://chatgpt.com/share/68064bfe-662c-8012-8073-479c32595459

# %% [markdown]
# 请多加练习，建立信心。
#
# ChatGPT、Claude、Gemini、DeepSeek 等都是你的朋友！它们非常擅长详细解释各种命令行命令。这些很快就会变成第二天性。
